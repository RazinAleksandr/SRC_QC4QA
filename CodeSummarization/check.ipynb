# %%
import pandas as pd
import pandas as pd
from tqdm import tqdm
import torch
from torch.utils.data import Dataset
import random

from transformers import RobertaTokenizer, T5ForConditionalGeneration, DataCollatorWithPadding

# %%
path_raw = '/home/st-aleksandr-razin/workspace/SRC_QC4QA/data/summarization/raw/python_QA_text_code_raw.csv'
path_code = '/home/st-aleksandr-razin/workspace/SRC_QC4QA/data/summarization/processed/code_question_df.csv'
path_described_code = '/home/st-aleksandr-razin/workspace/SRC_QC4QA/data/summarization/processed/code_question_described_df.csv'
question_with_code_description_path = '/home/st-aleksandr-razin/workspace/SRC_QC4QA/data/summarization/processed/question_with_code_description.csv'

# %%
class CodeDataset(Dataset):
    def __init__(self, code_question_df, tokenizer):
        self.code_snippets = code_question_df['code_snippet'].tolist()
        self.indices = torch.arange(len(self.code_snippets))
        self.tokenizer = tokenizer

    def __len__(self):
        return len(self.code_snippets)

    def __getitem__(self, index):
        code_snippet = self.code_snippets[index]
        encoded_input = self.tokenizer.encode_plus(
            code_snippet,
            padding=True,
            truncation=True,
            return_tensors="pt"
        )
        input_ids = encoded_input["input_ids"]
        return {"input_ids": input_ids[0], "index": index}

# %%
class DataPreprocessing:
    def __init__(self, df=None, columns=['Id_Q', 'Title_Q', 'Body_Q', 'Tags_Q', 'Code_Q']):
        self.df = df[columns].drop_duplicates()
    
    def preprocess_tags(self):
        self.df['Tags_Q'] = self.df['Tags_Q'].apply(lambda x: x.split(','))
    
    def indexing_code(self):
        self.code_df = self.df[self.df['Code_Q']][['Id_Q']]
    
    def get_code_question_dataframe(self):
        code_question_data = []
        start_tag = '<pre><code>'
        end_tag = '</code></pre>'
        
        for index, row in tqdm(self.df.iterrows()):
            if row['Id_Q'] in self.code_df['Id_Q'].values and pd.notnull(row['Body_Q']):
                text = row['Body_Q']
                start_index = text.find(start_tag)
                pos_code = 0
                while start_index != -1:
                    end_index = text.find(end_tag, start_index)
                    
                    if end_index != -1:
                        code_snippet = text[start_index + len(start_tag):end_index]
                        code_question_data.append({'code_id': pos_code, 'code_snippet': code_snippet,'question_id': row['Id_Q']})
                        pos_code += 1
                        start_index = text.find(start_tag, end_index)
                    else:
                        break
        code_question_df = pd.DataFrame(code_question_data)
        return code_question_df
    
    def generate_code_descriptions(self, tokenizer, model, code_question_df, batch_size=64):
        code_question_df['code_description'] = ''
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        model = model.to(device)

        dataset = CodeDataset(code_question_df, tokenizer)
        dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, collate_fn=DataCollatorWithPadding(tokenizer, padding=True))

        for batch in tqdm(dataloader):
            #batch_indices = batch_indices.tolist()

            with torch.no_grad():
                generated_ids = model.generate(batch["input_ids"].to(device), max_length=20)

            descriptions = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
            
            for i, description in enumerate(descriptions):
                index = int(batch['index'][i])
                code_question_df.loc[index, 'code_description'] = str(description)

        return code_question_df

    def substitute_code_with_description(self, code_df):
        for row in tqdm(code_df.itertuples()):
            code_id = row.code_id
            question_id = row.question_id
            description = row.code_description
            code_snip = row.code_snippet
            
            # Find the corresponding question based on question ID
            
            try:
                question = self.df.loc[self.df['Id_Q'] == question_id, 'Body_Q'].values[0]
            except:
                print(self.df.loc[self.df['Id_Q'] == question_id, 'Body_Q'])
                print(self.df.loc[self.df['Id_Q'] == question_id, 'Body_Q'].values[0])
            
            # Replace the code with its description in the question
            question = question.replace(f'<pre><code>{code_snip}</code></pre>', f'code description start: {description} code description end')
            
            # Update the question in the question DataFrame
            self.df.loc[self.df['Id_Q'] == question_id, 'Body_Q'] = question
        
        return self.df

# %%
df = pd.read_csv(path_raw, index_col=0)
df = df.sample(100)

# %%
df
# Out:
#             Id_Q  AcceptedAnswerId_Q              CreationDate_Q  Score_Q  \
# 82770    6841853           6842138.0  2011-07-27 09:05:31.300000       20
# 124453  24689331                 NaN  2014-07-11 02:47:27.143000        0
# 255427  65341580                 NaN  2020-12-17 13:23:06.773000        0
# 11502    4180836           4180882.0     2010-11-15 01:46:21.097       19
# 16681    7451163           7466485.0     2011-09-16 22:55:27.807        0
# ...          ...                 ...                         ...      ...
# 258713  66153527          66154139.0  2021-02-11 11:06:23.463000        0
# 122890  23997403                 NaN  2014-06-02 14:50:34.593000       54
# 50859   55538285          55538436.0     2019-04-05 14:59:50.507        0
# 17944    8630573           8630649.0     2011-12-25 17:08:04.547        3
# 37703   37026175                 NaN     2016-05-04 11:13:12.503        0
#
#         ViewCount_Q                                             Body_Q  \
# 82770         24479  <p>I'm currently learning Python, and I have t...
# 124453         1675  <p>I'm a beginner to flask, following the inst...
# 255427           65  <p>I want to kick members that have a specific...
# 11502          9169  <p><strong>How practical would it be to use Cy...
# 16681           143  <p>My Python High Replication Datastore applic...
# ...             ...                                                ...
# 258713           84  <p>I am trying to load a pickle file that the ...
# 122890        70352  <p>Lots of other threads about similar issues,...
# 50859            49  <p>Like if i want paragraph to be on monday. A...
# 17944          9002  <p>I have a web crawling python script running...
# 37703          1028  <p>Currently in my work placement, I have to c...
#
#                                                   Title_Q  \
# 82770                       accessing "module scope" vars
# 124453                              no module named flask
# 255427  discord py - How do I check if a member has a ...
# 11502                  Using Cython for game development?
# 16681    GAE Lookup Table Incompatible with Transactions?
# ...                                                   ...
# 258713  Loading a pickle file returns 'could not find ...
# 122890  Installed virtualenv and virtualenvwrapper: Py...
# 50859           Is there a way to display a view by date?
# 17944    How to pause a python script running in terminal
# 37703   Python, Tkinter, embed an interactive console ...
#
#                                                    Tags_Q  AnswerCount_Q  \
# 82770          python,variables,module,scope,coding-style              4
# 124453                                       python,flask              2
# 255427    python,python-3.x,discord.py,discord.py-rewrite              1
# 11502                                     python,c,cython              6
# 16681   python,google-app-engine,transactions,google-c...              2
# ...                                                   ...            ...
# 258713                                      python,pickle              1
# 122890          python,macos,virtualenv,virtualenvwrapper             10
# 50859                                       python,django              3
# 17944                   python,terminal,pausing-execution              6
# 37703                 python,tkinter,console,stdout,xterm              1
#
#         CommentCount_Q  Link_Q  Code_Q  Image_Q      Id_A  \
# 82770                1   False    True    False   6842102
# 124453               3   False    True    False  24689931
# 255427               2   False    True    False  65343785
# 11502                2   False   False    False  17047294
# 16681                0   False   False    False   7452303
# ...                ...     ...     ...      ...       ...
# 258713               6   False    True    False  66154139
# 122890               2   False    True    False  44194250
# 50859                2   False   False    False  55538379
# 17944                2   False   False    False   8631087
# 37703                5   False   False    False  37031498
#
#                     CreationDate_A  Score_A  \
# 82770   2011-07-27 09:29:17.003000        1
# 124453  2014-07-11 04:04:28.980000        0
# 255427  2020-12-17 15:39:05.717000        0
# 11502      2013-06-11 14:57:30.433        0
# 16681      2011-09-17 03:46:07.917        1
# ...                            ...      ...
# 258713  2021-02-11 11:46:09.047000        0
# 122890  2017-05-26 05:30:26.477000        7
# 50859      2019-04-05 15:03:42.680        0
# 17944      2011-12-25 19:10:56.307        1
# 37703      2016-05-04 15:02:02.287        0
#
#                                                    Body_A  Link_A  Code_A  \
# 82770   <p>Avoid setting globals at all. You can creat...   False   False
# 124453  <h1>Virtualenv is always activated locally for...   False   False
# 255427  <p>Even though I do not believe Discord saves ...   False   False
# 11502   <p>I know Cython and you do not have to know C...   False   False
# 16681   <p>First, if you're under the belief that a na...   False   False
# ...                                                   ...     ...     ...
# 258713  <p>I had accidentally deleted <code>save_game_...   False   False
# 122890  <p>try installing virtualenv and virtualenvwra...   False   False
# 50859   <ol>\n<li>regexp on url</li>\n<li>route in vie...   False   False
# 17944   <p>Since you're populating a database with you...   False   False
# 37703   <p>You should start with an analysis of what y...   False   False
#
#         Image_A
# 82770     False
# 124453    False
# 255427    False
# 11502     False
# 16681     False
# ...         ...
# 258713    False
# 122890    False
# 50859     False
# 17944     False
# 37703     False
#
# [100 rows x 20 columns]

# %%
preprocessing = DataPreprocessing(df)
preprocessing.preprocess_tags()
preprocessing.indexing_code()

# %%
preprocessing.df
# Out:
#             Id_Q                                            Title_Q  \
# 82770    6841853                      accessing "module scope" vars
# 124453  24689331                              no module named flask
# 255427  65341580  discord py - How do I check if a member has a ...
# 11502    4180836                 Using Cython for game development?
# 16681    7451163   GAE Lookup Table Incompatible with Transactions?
# ...          ...                                                ...
# 258713  66153527  Loading a pickle file returns 'could not find ...
# 122890  23997403  Installed virtualenv and virtualenvwrapper: Py...
# 50859   55538285          Is there a way to display a view by date?
# 17944    8630573   How to pause a python script running in terminal
# 37703   37026175  Python, Tkinter, embed an interactive console ...
#
#                                                    Body_Q  \
# 82770   <p>I'm currently learning Python, and I have t...
# 124453  <p>I'm a beginner to flask, following the inst...
# 255427  <p>I want to kick members that have a specific...
# 11502   <p><strong>How practical would it be to use Cy...
# 16681   <p>My Python High Replication Datastore applic...
# ...                                                   ...
# 258713  <p>I am trying to load a pickle file that the ...
# 122890  <p>Lots of other threads about similar issues,...
# 50859   <p>Like if i want paragraph to be on monday. A...
# 17944   <p>I have a web crawling python script running...
# 37703   <p>Currently in my work placement, I have to c...
#
#                                                    Tags_Q  Code_Q
# 82770    [python, variables, module, scope, coding-style]    True
# 124453                                    [python, flask]    True
# 255427  [python, python-3.x, discord.py, discord.py-re...    True
# 11502                                 [python, c, cython]   False
# 16681   [python, google-app-engine, transactions, goog...   False
# ...                                                   ...     ...
# 258713                                   [python, pickle]    True
# 122890     [python, macos, virtualenv, virtualenvwrapper]    True
# 50859                                    [python, django]   False
# 17944               [python, terminal, pausing-execution]   False
# 37703           [python, tkinter, console, stdout, xterm]   False
#
# [100 rows x 5 columns]

# %%
preprocessing.code_df
# Out:
#             Id_Q
# 82770    6841853
# 124453  24689331
# 255427  65341580
# 244058  62709539
# 135942  29742727
# ...          ...
# 225804  58457790
# 70225    2291069
# 137436  30352616
# 258713  66153527
# 122890  23997403
#
# [72 rows x 1 columns]

# %%
code_question_df = preprocessing.get_code_question_dataframe()
# Out:
# 100it [00:00, 11160.11it/s]

# %%
preprocessing.df.iloc[0, 2]
# Out:
# '<p>I\'m currently learning Python, and I have to work on a Python 2.7 project.</p>\n\n<p>Accessing "module scope" variables in functions of the module itself is a bit confusing for me, and I didn\'t succeed in finding a satisfying way.</p>\n\n<p>My attempts so far:</p>\n\n<p><strong>Way 1:</strong></p>\n\n<p>my_module.py</p>\n\n<pre><code>my_global_var = None\n\ndef my_func():\n    global my_global_var\n    my_global_var = \'something_else\'\n</code></pre>\n\n<p>Here I think that confusing local and "module scope" vars may be quite easy.</p>\n\n<p><strong>Way 2:</strong></p>\n\n<p>my_module.py</p>\n\n<pre><code>import my_module\n\nmy_global_var = None\n\ndef my_func():\n    my_module.my_global_var = \'something_else\'\n</code></pre>\n\n<p>Here, the name of "my_module" could not be as easily changed as "way 1" when necessary. Plus, importing a module into itself sounds quite weird.</p>\n\n<p>What would you recommend? Or would you suggest something else? Thanks.</p>\n'

# %%
code_question_df
# Out:
#      code_id                                       code_snippet  question_id
# 0          0  my_global_var = None\n\ndef my_func():\n    gl...      6841853
# 1          1  import my_module\n\nmy_global_var = None\n\nde...      6841853
# 2          0  $ mkdir myproject\n$ cd myproject\n$ virtualen...     24689331
# 3          0  if role in member.roles for 30 days:\n   await...     65341580
# 4          0  import any_dict_01\nimport json\n\ndata = any_...     62709539
# ..       ...                                                ...          ...
# 145        3  &lt;p&gt;The exit of the view was: {{ MyProjec...     30352616
# 146        4  &lt;object width="400" height="400" data="/pat...     30352616
# 147        0  from pprint import pprint\nimport random\nimpo...     66153527
# 148        0  export PATH=/usr/local/bin:$PATH\nexport PIP_D...     23997403
# 149        1  New python executable in trunk/bin/python\nIns...     23997403
#
# [150 rows x 3 columns]

# %%
sampled_question_ids = random.sample(code_question_df['question_id'].unique().tolist(), 50)

# %%
sampled_question_ids
# Out:
# [56129786,
#  51625542,
#  20792049,
#  24689331,
#  59199224,
#  25241692,
#  7116526,
#  23997403,
#  13303449,
#  55093747,
#  33213057,
#  61559413,
#  58041059,
#  46244850,
#  39651222,
#  23914370,
#  70778175,
#  12809466,
#  58457790,
#  13062306,
#  57566344,
#  17108924,
#  72381032,
#  44172637,
#  54336776,
#  6841853,
#  30352616,
#  71182388,
#  33484107,
#  2291069,
#  30662920,
#  45619741,
#  10922134,
#  14504990,
#  53322171,
#  5208436,
#  16215605,
#  62768787,
#  26695219,
#  7252681,
#  65341580,
#  64765578,
#  61679864,
#  32455262,
#  9163640,
#  22871871,
#  22827671,
#  44660433,
#  46620035,
#  28075108]

# %%
filtered_code_df = code_question_df[code_question_df['question_id'].isin(sampled_question_ids)]

# %%
filtered_code_df
# Out:
#      code_id                                       code_snippet  question_id
# 0          0  my_global_var = None\n\ndef my_func():\n    gl...      6841853
# 1          1  import my_module\n\nmy_global_var = None\n\nde...      6841853
# 2          0  $ mkdir myproject\n$ cd myproject\n$ virtualen...     24689331
# 3          0  if role in member.roles for 30 days:\n   await...     65341580
# 7          0  def func(a, b):\n\n  if a &gt;= 0 and b &gt; 0...     53322171
# ..       ...                                                ...          ...
# 144        2  &lt;p&gt;The exit of the view was: &lt;?HTML_T...     30352616
# 145        3  &lt;p&gt;The exit of the view was: {{ MyProjec...     30352616
# 146        4  &lt;object width="400" height="400" data="/pat...     30352616
# 148        0  export PATH=/usr/local/bin:$PATH\nexport PIP_D...     23997403
# 149        1  New python executable in trunk/bin/python\nIns...     23997403
#
# [115 rows x 3 columns]

# %%
tokenizer = RobertaTokenizer.from_pretrained('Salesforce/codet5-base-multi-sum')
model = T5ForConditionalGeneration.from_pretrained('Salesforce/codet5-base-multi-sum')

# %%
filtered_code_df['code_description'] = ''
filtered_code_df
# Out:
# /tmp/ipykernel_792802/4112970640.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_code_df['code_description'] = ''
#      code_id                                       code_snippet  question_id  \
# 0          0  my_global_var = None\n\ndef my_func():\n    gl...      6841853
# 1          1  import my_module\n\nmy_global_var = None\n\nde...      6841853
# 2          0  $ mkdir myproject\n$ cd myproject\n$ virtualen...     24689331
# 3          0  if role in member.roles for 30 days:\n   await...     65341580
# 7          0  def func(a, b):\n\n  if a &gt;= 0 and b &gt; 0...     53322171
# ..       ...                                                ...          ...
# 144        2  &lt;p&gt;The exit of the view was: &lt;?HTML_T...     30352616
# 145        3  &lt;p&gt;The exit of the view was: {{ MyProjec...     30352616
# 146        4  &lt;object width="400" height="400" data="/pat...     30352616
# 148        0  export PATH=/usr/local/bin:$PATH\nexport PIP_D...     23997403
# 149        1  New python executable in trunk/bin/python\nIns...     23997403
#
#     code_description
# 0
# 1
# 2
# 3
# 7
# ..               ...
# 144
# 145
# 146
# 148
# 149
#
# [115 rows x 4 columns]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
filtered_code_df.reset_index(inplace=True, drop=True)

# %%
dataset = CodeDataset(filtered_code_df, tokenizer)
dataloader = torch.utils.data.DataLoader(dataset, batch_size=16, collate_fn=DataCollatorWithPadding(tokenizer, padding=True), shuffle=False)

# %%
filtered_code_df
# Out:
#      code_id                                       code_snippet  question_id  \
# 0          0  my_global_var = None\n\ndef my_func():\n    gl...      6841853
# 1          1  import my_module\n\nmy_global_var = None\n\nde...      6841853
# 2          0  $ mkdir myproject\n$ cd myproject\n$ virtualen...     24689331
# 3          0  if role in member.roles for 30 days:\n   await...     65341580
# 4          0  def func(a, b):\n\n  if a &gt;= 0 and b &gt; 0...     53322171
# ..       ...                                                ...          ...
# 110        2  &lt;p&gt;The exit of the view was: &lt;?HTML_T...     30352616
# 111        3  &lt;p&gt;The exit of the view was: {{ MyProjec...     30352616
# 112        4  &lt;object width="400" height="400" data="/pat...     30352616
# 113        0  export PATH=/usr/local/bin:$PATH\nexport PIP_D...     23997403
# 114        1  New python executable in trunk/bin/python\nIns...     23997403
#
#     code_description
# 0
# 1
# 2
# 3
# 4
# ..               ...
# 110
# 111
# 112
# 113
# 114
#
# [115 rows x 4 columns]

# %%
for batch in tqdm(dataloader):
    with torch.no_grad():
        generated_ids = model.generate(batch["input_ids"].to(device), max_length=20)
    descriptions = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
    for i, description in enumerate(descriptions):
        index = int(batch['index'][i])
        filtered_code_df.loc[index, 'code_description'] = str(description)
# Out:
# 100%|██████████| 8/8 [00:03<00:00,  2.05it/s]

# %%
filtered_code_df
# Out:
#      code_id                                       code_snippet  question_id  \
# 0          0  my_global_var = None\n\ndef my_func():\n    gl...      6841853
# 1          1  import my_module\n\nmy_global_var = None\n\nde...      6841853
# 2          0  $ mkdir myproject\n$ cd myproject\n$ virtualen...     24689331
# 3          0  if role in member.roles for 30 days:\n   await...     65341580
# 4          0  def func(a, b):\n\n  if a &gt;= 0 and b &gt; 0...     53322171
# ..       ...                                                ...          ...
# 110        2  &lt;p&gt;The exit of the view was: &lt;?HTML_T...     30352616
# 111        3  &lt;p&gt;The exit of the view was: {{ MyProjec...     30352616
# 112        4  &lt;object width="400" height="400" data="/pat...     30352616
# 113        0  export PATH=/usr/local/bin:$PATH\nexport PIP_D...     23997403
# 114        1  New python executable in trunk/bin/python\nIns...     23997403
#
#                                       code_description
# 0    This function is a wrapper around the global v...
# 1    A function to define a function that will be c...
# 2    Create a missing system environment if it does...
# 3                         Kick the member for 30 days.
# 4    Calculate the n - th index of a to n - th inde...
# ..                                                 ...
# 110  Displays a message that shows the exit of the ...
# 111                                  Exit of the view.
# 112  This is a simple example of how to render a si...
# 113        Exports environment variables for n - node.
# 114                    New python executable in trunk.
#
# [115 rows x 4 columns]

# %%
import pandas as pd

# %%
question_with_code_description = pd.read_csv('/home/st-aleksandr-razin/workspace/SRC_QC4QA/data/summarization/final/question_with_code_description.csv')
question_with_code_description
# Out:
#            Id_Q                                            Title_Q  \
# 0          1476      How do you express binary literals in Python?
# 1         20927  Updating an auto_now DateTimeField in a parent...
# 2         59825  How to retrieve an element from a set without ...
# 3         61605  Is it pythonic for a function to return multip...
# 4         65266          Caching compiled regex objects in Python?
# ...         ...                                                ...
# 49990  72498913  Pyngrok & Flask, Your account is limited to 1 ...
# 49991  72500796  How to fix ModuleNotFoundError: No module name...
# 49992  72502170         How to drop duplicates ignoring one column
# 49993  72502242  django.db.utils.ProgrammingError: relation "ap...
# 49994  72505151  Printing gives the answer I want, but returnin...
#
#                                                   Body_Q  \
# 0      <p>How do you express an integer as a binary n...
# 1      <p>I've got two models: Message and Attachment...
# 2      <p>Suppose the following:</p>\n\ncode descript...
# 3      <p>In python, you can have a function return m...
# 4      <p>Each time a python file is imported that co...
# ...                                                  ...
# 49990  <p>I trying to run both flask and ngrok in the...
# 49991  <p>I have currently installed the terra_sdk==2...
# 49992  <p>I have a <code>DataFrame</code> with multip...
# 49993  <p>After I deleted all the migration files and...
# 49994  <p>I'm quite new to python and ive been practi...
#
#                                                   Tags_Q  Code_Q
# 0      ['python', 'syntax', 'binary', 'integer', 'lit...    True
# 1                ['python', 'database', 'django', 'orm']    True
# 2                                      ['python', 'set']    True
# 3      ['python', 'function', 'return-value', 'multip...    True
# 4                         ['python', 'regex', 'caching']    True
# ...                                                  ...     ...
# 49990  ['python', 'r', 'python-3.x', 'flask', 'pyngrok']    True
# 49991                                ['python', 'terra']    True
# 49992                               ['python', 'pandas']    True
# 49993          ['python', 'django', 'django-migrations']    True
# 49994                 ['python', 'python-3.x', 'return']    True
#
# [49995 rows x 5 columns]

# %%
import ast

# %%
question_with_code_description['Tags_Q'][0]
# Out:
# "['python', 'syntax', 'binary', 'integer', 'literals']"

# %%
question_with_code_description['Tags_Q'] = question_with_code_description['Tags_Q'].apply(lambda x: ast.literal_eval(x)) #convert to list type

# %%
question_with_code_description['Tags_Q'][0]
# Out:
# ['python', 'syntax', 'binary', 'integer', 'literals']

# %%
exploded_df = question_with_code_description.explode('Tags_Q')
exploded_df.head()
# Out:
#    Id_Q                                        Title_Q  \
# 0  1476  How do you express binary literals in Python?
# 0  1476  How do you express binary literals in Python?
# 0  1476  How do you express binary literals in Python?
# 0  1476  How do you express binary literals in Python?
# 0  1476  How do you express binary literals in Python?
#
#                                               Body_Q    Tags_Q  Code_Q
# 0  <p>How do you express an integer as a binary n...    python    True
# 0  <p>How do you express an integer as a binary n...    syntax    True
# 0  <p>How do you express an integer as a binary n...    binary    True
# 0  <p>How do you express an integer as a binary n...   integer    True
# 0  <p>How do you express an integer as a binary n...  literals    True

# %%
val = pd.read_csv('/home/st-aleksandr-razin/workspace/SRC_QC4QA/QC_pipeline/dataset/train_vsl_data/val.csv')

# %%
for j, i in enumerate(question_with_code_description_raw['Title_Q'].values):
    if 'Update the view less often' in i:
        print(j)
        break
# Out:
# 7368

# %%
question_with_code_description_raw = pd.read_csv('/home/st-aleksandr-razin/workspace/SRC_QC4QA/data/summarization/final/question_with_code_description_raw.csv')

# %%
print(question_with_code_description_raw.iloc[7368]['Body_Q'])
# Out:
# <p>I developed a program in a QMainWindow, with a QTableView based on a QSqlTableModel. The database uses sqlite. </p>
#
# <p>This program is supposed to display a list of videos. I can normally add some tags and actor to each video (tags and actors are stored in the database). When I have a few videos displayed, everything works fine, but when the number of videos increases, my program raises an exception like that:</p>
#
# <pre><code>Traceback (most recent call last):
# File "/home/djipey/informatique/python/bibli/gui.py", line 572, in addTag
# liste.addTag(vids_selected, tag_to_add.split(" "))
# File "/home/djipey/informatique/python/bibli/liste.py", line 488, in addTag
# bdd.commit()
# sqlite3.OperationalError: database is locked
# </code></pre>
#
# <p>I'm almost sure the problem doesn't come from liste.py, because I close each connection and cursor. No, my database is busy somewhere else.</p>
#
# <p>I assume the problem comes from the view/model when they display the informations, so I wonder if it's possible to dicrease the display rate? Otherwise, I'm open to every suggestion to fix the problem.</p>
#
# <pre><code>def addTag(list_vids, list_tags):
#
#     """ Ajoute tous les tags de list_tags à chaque vid de list_vids. Pour
# cela crée un tag dans la table tags, puis établit une relation entre
# l'id de la vidéo et l'id du tag créé. Inscrit la correspondance dans
# la table videos_tags. """
#
#     bdd = sqlite3.connect("fichiers.sqlite") # ouverture de la base
#     bdd.row_factory = sqlite3.Row # accès aux colonnes par leur nom, pas par leur index
#
#     c = bdd.cursor() # obtention d'un curseur
#
#     #On ajoute le tag transmis à la table tags s'il n'existe pas déjà
#     for each_tag in list_tags:
#         c.execute("SELECT * FROM tags WHERE name= ? ", (each_tag,))
#         if c.fetchone() is None:
#             c.execute("INSERT INTO tags (name) VALUES (?) ", (each_tag,))
#
#             bdd.commit()
#
#     for each_video in list_vids:
#         for each_tag in list_tags:
#             #On récupère l'id du tag pour s'en servir après
#             c.execute("SELECT id FROM tags WHERE name= ?", (each_tag,))
#             id_tag_recupere = c.fetchone()["id"]
#
#             #On vérifie que le tag à stocker n'est pas déjà associé à la vidéo
#             c.execute("SELECT * FROM videos_tags WHERE id_video = ? AND id_tag = ?", (each_video, id_tag_recupere))
#             if c.fetchone() is None:
#                 c.execute("INSERT INTO videos_tags (id_video, id_tag) VALUES (?, ?)", (each_video, id_tag_recupere))
#                 bdd.commit()
#             else:
#                 print("Cette vidéo a déjà ce tag")
#
#     c.close()
# </code></pre>

# %%
print(val.iloc[-1]['Text'])
# Out:
# title: Update the view less often
# question: <p>I developed a program in a QMainWindow, with a QTableView based on a QSqlTableModel. The database uses sqlite. </p>
#
# <p>This program is supposed to display a list of videos. I can normally add some tags and actor to each video (tags and actors are stored in the database). When I have a few videos displayed, everything works fine, but when the number of videos increases, my program raises an exception like that:</p>
#
# code description start: Traceback is called when the last call to addTag
#  is called. code description end
#
# <p>I'm almost sure the problem doesn't come from liste.py, because I close each connection and cursor. No, my database is busy somewhere else.</p>
#
# <p>I assume the problem comes from the view/model when they display the informations, so I wonder if it's possible to dicrease the display rate? Otherwise, I'm open to every suggestion to fix the problem.</p>
#
# code description start: Add a tag to list_tags. code description end

# %%
tags_count = exploded_df['Tags_Q'].value_counts()

# %%
for i, tag in zip(tags_count.index, tags_count):
    print(i, tag)
# Out:
# python 45884
# python-3.x 6713
# django 4597
# python-2.7 2683
# pandas 2451
# numpy 1596
# list 1296
# tensorflow 1199
# tkinter 1076
# flask 1019
# dictionary 807
# keras 781
# pip 736
# regex 721
# string 713
# dataframe 702
# selenium 684
# json 660
# machine-learning 632
# matplotlib 615
# mysql 613
# csv 590
# scikit-learn 574
# linux 554
# arrays 553
# function 540
# google-app-engine 506
# class 495
# sockets 494
# pygame 493
# multithreading 493
# django-models 486
# opencv 484
# for-loop 455
# windows 452
# html 441
# python-requests 421
# loops 404
# sqlalchemy 402
# macos 402
# algorithm 360
# anaconda 351
# sqlite 346
# deep-learning 343
# postgresql 342
# pycharm 342
# beautifulsoup 341
# file 330
# import 327
# subprocess 326
# javascript 324
# web-scraping 323
# jupyter-notebook 321
# sql 319
# amazon-web-services 317
# multiprocessing 312
# scipy 306
# c++ 304
# django-rest-framework 289
# docker 281
# neural-network 280
# if-statement 276
# kivy 275
# ubuntu 272
# performance 268
# recursion 266
# module 263
# selenium-webdriver 262
# oop 257
# virtualenv 257
# datetime 256
# scrapy 250
# discord.py 247
# django-views 240
# pyspark 236
# while-loop 233
# excel 232
# python-import 226
# ipython 224
# unicode 222
# xml 220
# unit-testing 217
# database 217
# pytorch 214
# bash 207
# wxpython 207
# variables 205
# pyqt 201
# mongodb 199
# heroku 198
# api 198
# apache-spark 197
# java 196
# raspberry-pi 194
# sorting 191
# image 191
# pyinstaller 187
# parsing 183
# django-forms 181
# logging 180
# python-imaging-library 176
# user-interface 173
# celery 172
# c 170
# python-3.6 170
# shell 169
# random 168
# django-templates 162
# tuples 158
# discord 157
# pickle 154
# nlp 153
# optimization 151
# php 149
# apache 148
# math 146
# typeerror 144
# inheritance 141
# visual-studio-code 140
# installation 140
# conda 140
# amazon-s3 136
# indexing 135
# encoding 135
# importerror 133
# android 130
# list-comprehension 129
# openpyxl 129
# exception 128
# aws-lambda 127
# flask-sqlalchemy 127
# matrix 127
# object 126
# tornado 124
# file-io 124
# image-processing 123
# email 121
# twitter 119
# conv-neural-network 118
# boto3 117
# pyqt5 115
# text 114
# utf-8 114
# syntax 114
# pytest 113
# psycopg2 113
# jquery 112
# http 112
# spyder 110
# time 110
# nltk 109
# qt 109
# pymongo 109
# python-asyncio 108
# jinja2 108
# ssl 105
# python-multiprocessing 105
# ctypes 105
# forms 105
# ajax 105
# terminal 104
# path 104
# jupyter 104
# mysql-python 104
# sql-server 102
# networking 102
# eclipse 102
# lambda 102
# xpath 101
# iteration 100
# openerp 99
# ssh 98
# floating-point 98
# django-admin 98
# rest 98
# lxml 97
# error-handling 96
# pyodbc 96
# memory 96
# generator 96
# google-cloud-platform 95
# python-multithreading 95
# pyqt4 95
# twisted 94
# input 94
# pydev 94
# debugging 94
# data-science 93
# cron 93
# methods 92
# data-structures 92
# nginx 91
# lstm 91
# urllib2 91
# odoo 91
# urllib 90
# selenium-chromedriver 90
# python-3.5 89
# plot 89
# package 88
# python-3.7 88
# tweepy 87
# paramiko 87
# printing 86
# setuptools 86
# git 85
# google-colaboratory 85
# tcp 84
# c# 84
# airflow 84
# testing 84
# types 83
# split 82
# python-2.x 82
# io 82
# gunicorn 81
# mod-wsgi 81
# attributeerror 81
# scope 80
# google-cloud-datastore 79
# set 79
# post 79
# css 78
# cgi 78
# cython 78
# global-variables 78
# replace 77
# parallel-processing 77
# web 76
# python-unittest 76
# uwsgi 75
# web-crawler 75
# python-3.4 74
# ironpython 74
# pyserial 74
# classification 73
# attributes 73
# computer-vision 72
# hash 72
# integer 72
# encryption 71
# syntax-error 71
# return 70
# python-module 70
# url 70
# amazon-ec2 70
# append 69
# request 69
# unix 69
# scapy 69
# elasticsearch 69
# directory 68
# webdriver 68
# authentication 68
# slice 67
# gtk 67
# turtle-graphics 67
# r 66
# node.js 66
# graph 65
# wsgi 65
# audio 64
# robotframework 64
# dask 63
# pygtk 62
# time-complexity 62
# gensim 62
# boolean 62
# tensorflow2.0 61
# py2exe 61
# asynchronous 61
# pdf 61
# decorator 61
# search 61
# redis 61
# hadoop 60
# arguments 60
# serialization 60
# nested 59
# websocket 59
# automation 59
# linear-regression 58
# azure 57
# statsmodels 57
# command-line 57
# date 57
# orm 57
# cx-freeze 56
# artificial-intelligence 56
# popen 56
# networkx 56
# boto 56
# udp 56
# vim 55
# oracle 55
# coding-style 54
# sympy 54
# matlab 54
# argparse 54
# int 54
# cmd 54
# templates 53
# docker-compose 53
# nameerror 53
# namespaces 53
# time-series 53
# pyramid 53
# stdout 52
# django-queryset 52
# iterator 52
# elementtree 52
# spacy 51
# exception-handling 51
# smtp 51
# model 51
# multidimensional-array 51
# statistics 51
# server 51
# pyside 51
# django-urls 50
# rabbitmq 50
# swig 50
# environment-variables 50
# ipython-notebook 49
# curl 49
# serial-port 49
# python-3.8 49
# bots 49
# button 48
# python-2.6 48
# fabric 48
# validation 48
# queue 48
# google-chrome 47
# seaborn 47
# xgboost 47
# plotly-dash 47
# boost-python 46
# proxy 46
# exe 46
# cx-oracle 46
# pywin32 46
# dll 46
# process 46
# indentation 46
# wxwidgets 46
# cryptography 46
# google-bigquery 45
# scripting 45
# theano 45
# bottle 45
# mocking 45
# pythonanywhere 45
# zip 44
# session 44
# valueerror 44
# cluster-analysis 44
# nonetype 44
# jython 43
# global 43
# operating-system 43
# range 43
# mechanize 43
# raspberry-pi3 42
# network-programming 42
# ffmpeg 42
# cherrypy 42
# python-idle 42
# pymysql 41
# arduino 41
# primes 41
# ansible 41
# setup.py 41
# boost 40
# character-encoding 40
# pyautogui 40
# merge 40
# pillow 40
# facebook 40
# pylint 40
# win32com 40
# concatenation 40
# conditional-statements 40
# pandas-groupby 40
# bokeh 39
# cv2 39
# centos 39
# distutils 39
# formatting 39
# mqtt 39
# filter 39
# big-o 38
# linked-list 38
# svm 38
# perl 38
# app-engine-ndb 38
# k-means 38
# word2vec 38
# sum 38
# apache-kafka 38
# parameters 38
# runtime-error 38
# kivy-language 38
# permissions 38
# text-files 37
# plotly 37
# jenkins 37
# key 37
# binary 37
# count 37
# debian 37
# output 37
# numbers 37
# telegram 36
# apache-beam 36
# byte 36
# tensor 36
# discord.py-rewrite 36
# cross-validation 36
# batch-file 36
# itertools 36
# reference 36
# tkinter-canvas 36
# google-cloud-storage 36
# python-3.3 36
# smtplib 36
# amazon-dynamodb 36
# gmail 36
# stdin 35
# recurrent-neural-network 35
# memory-management 35
# django-celery 35
# django-orm 35
# powershell 35
# random-forest 35
# telegram-bot 34
# django-migrations 34
# opengl 34
# openssl 34
# mapreduce 34
# garbage-collection 34
# dockerfile 34
# visual-studio 34
# keyerror 34
# pdb 34
# tree 34
# reportlab 34
# properties 33
# ruby 33
# design-patterns 33
# hdf5 33
# caching 33
# gevent 33
# maya 33
# operators 33
# python-telegram-bot 33
# self 33
# windows-7 33
# security 33
# homebrew 32
# cassandra 32
# duplicates 32
# raspbian 32
# nested-lists 32
# comparison 32
# break 32
# github 32
# numpy-ndarray 32
# regression 32
# mongoengine 32
# object-detection 32
# firefox 31
# firebase 31
# format 31
# odoo-8 31
# fastapi 31
# flask-restful 31
# variable-assignment 31
# xlrd 31
# canvas 31
# python-decorators 31
# pythonpath 31
# python-sphinx 31
# pipenv 31
# logistic-regression 31
# instance 31
# memory-leaks 31
# google-api 31
# widget 31
# counter 30
# concurrency 30
# try-catch 30
# windows-10 30
# zeromq 30
# xlsxwriter 30
# deployment 30
# xml-parsing 30
# cookies 30
# numba 30
# nested-loops 30
# angularjs 30
# events 29
# get 29
# ubuntu-16.04 29
# pyglet 29
# nose 29
# web2py 29
# shutil 29
# opencv3.0 29
# buildozer 29
# rpy2 29
# easy-install 28
# pylons 28
# tastypie 28
# backend 28
# webapp2 28
# callback 28
# pypi 28
# join 28
# timer 28
# kubernetes 28
# sublimetext3 28
# aiohttp 28
# hex 28
# save 28
# django-settings 28
# pipe 28
# html-parsing 28
# newline 28
# outlook 28
# flask-wtforms 28
# type-conversion 28
# return-value 28
# client 28
# sklearn-pandas 27
# google-cloud-functions 27
# scrapy-spider 27
# tk 27
# supervisord 27
# ascii 27
# vba 27
# django-south 27
# apache-spark-sql 27
# yaml 27
# sys 27
# apscheduler 27
# scikit-image 27
# animation 27
# try-except 27
# web.py 27
# emacs 27
# web-services 27
# sentiment-analysis 27
# reactjs 27
# .net 27
# oauth 27
# nan 27
# decision-tree 27
# python-venv 26
# struct 26
# packages 26
# window 26
# select 26
# ldap 26
# colors 26
# timestamp 26
# gpu 26
# gstreamer 26
# initialization 26
# speech-recognition 26
# pointers 26
# caffe 26
# pool 26
# odoo-10 26
# video 26
# copy 26
# peewee 25
# enumerate 25
# gcc 25
# histogram 25
# pyaudio 25
# django-staticfiles 25
# sequence 25
# user-input 25
# ttk 25
# permutation 25
# signals 25
# max 25
# google-cloud-dataflow 25
# decode 25
# sparse-matrix 25
# tkinter-entry 25
# ftp 25
# tf.keras 24
# timeout 24
# h5py 24
# ubuntu-14.04 24
# cpython 24
# bioinformatics 24
# command-line-arguments 24
# https 24
# urllib3 24
# base64 24
# neo4j 24
# prediction 24
# mariadb 24
# pycrypto 24
# compiler-errors 24
# rounding 24
# console 24
# python-xarray 24
# pipeline 23
# passwords 23
# netcdf 23
# socket.io 23
# python-datetime 23
# gdal 23
# knn 23
# imaplib 23
# cmake 23
# ftplib 23
# traceback 23
# imap 23
# django-authentication 23
# ros 23
# python-unicode 23
# gpio 23
# pexpect 23
# screen-scraping 23
# soap 23
# paho 23
# constructor 23
# escaping 23
# bigdata 23
# decimal 22
# compilation 22
# pymssql 22
# infinite-loop 22
# redirect 22
# linear-algebra 22
# migration 22
# glob 22
# compression 22
# curve-fitting 22
# interpreter 22
# text-classification 22
# python-tesseract 22
# models 22
# eval 22
# gzip 22
# python-sockets 22
# pywinauto 22
# dynamic 21
# google-drive-api 21
# out-of-memory 21
# parquet 21
# apache2 21
# django-class-based-views 21
# fonts 21
# awk 21
# docstring 21
# fortran 21
# winapi 21
# conditional 21
# data-analysis 21
# subclass 21
# py2app 21
# huggingface-transformers 21
# functional-programming 21
# python-docx 20
# login 20
# mypy 20
# crontab 20
# flask-socketio 20
# gurobi 20
# iterable 20
# parameter-passing 20
# word-embedding 20
# index-error 20
# os.system 20
# raspberry-pi2 20
# protocol-buffers 20
# ios 20
# pycurl 20
# many-to-many 20
# gradient-descent 20
# precision 20
# grpc 20
# django-channels 20
# sudo 20
# foreign-keys 20
# substring 20
# reinforcement-learning 20
# pep8 20
# file-upload 20
# interpolation 20
# readline 20
# modelform 20
# init 20
# flask-login 20
# warnings 20
# calculator 20
# keras-layer 19
# simulation 19
# automated-tests 19
# rsa 19
# django-cms 19
# grid 19
# download 19
# segmentation-fault 19
# sprite 19
# facebook-graph-api 19
# tensorflow-datasets 19
# ssl-certificate 19
# string-formatting 19
# scheduled-tasks 19
# suds 19
# series 19
# gtk3 19
# static 19
# ubuntu-18.04 19
# jira 19
# enthought 19
# python-turtle 19
# runtime 19
# with-statement 19
# web-applications 19
# pyomo 19
# combinations 19
# ip 19
# mod-python 18
# canopy 18
# makefile 18
# binary-search 18
# pika 18
# exit 18
# yield 18
# graphviz 18
# hive 18
# command-line-interface 18
# tesseract 18
# jupyter-lab 18
# geopandas 18
# django-testing 18
# webserver 18
# file-handling 18
# coroutine 18
# enums 18
# mnist 18
# vector 18
# encode 18
# python-c-api 18
# super 18
# librosa 18
# keyboard 18
# google-api-python-client 18
# cygwin 18
# pca 18
# exec 18
# concurrent.futures 18
# overriding 18
# python-3.9 18
# executable 18
# quicksort 17
# com 17
# sftp 17
# torch 17
# dataset 17
# logic 17
# odbc 17
# biopython 17
# python-re 17
# databricks 17
# wtforms 17
# autocomplete 17
# webdriverwait 17
# pyzmq 17
# phantomjs 17
# insert 17
# blender 17
# binary-tree 17
# training-data 17
# keyword-argument 17
# ocr 17
# pulp 17
# aes 17
# xcode 17
# amazon-elastic-beanstalk 17
# python-behave 17
# add 17
# built-in 17
# python-packaging 17
# command 17
# probability 17
# xlwings 17
# raw-input 17
# gspread 17
# bit-manipulation 16
# igraph 16
# linear-programming 16
# geometry 16
# moviepy 16
# graph-theory 16
# gdb 16
# user-defined-functions 16
# pysnmp 16
# pypy 16
# instagram 16
# geckodriver 16
# graphics 16
# 3d 16
# apply 16
# miniconda 16
# reshape 16
# pyside2 16
# sed 16
# dns 16
# chatbot 16
# extract 16
# stack 16
# strip 16
# configuration 16
# dynamic-programming 16
# average 16
# amazon-sagemaker 16
# tokenize 16
# group-by 16
# kaggle 16
# reverse 16
# pyenv 16
# dbus 16
# latex 16
# ioerror 16
# oauth-2.0 16
# closures 16
# face-recognition 16
# irc 16
# sleep 16
# daemon 16
# depth-first-search 15
# filenames 15
# tags 15
# freeze 15
# amazon-redshift 15
# mmap 15
# httprequest 15
# dlib 15
# os.walk 15
# build 15
# label 15
# export 15
# md5 15
# lmfit 15
# gis 15
# tensorboard 15
# pypdf2 15
# refactoring 15
# division 15
# kernel 15
# multiple-inheritance 15
# camera 15
# dependencies 15
# assert 15
# shared-libraries 15
# view 15
# binary-search-tree 15
# python-os 15
# appium 15
# tf-idf 15
# loss-function 15
# null 15
# mysql-connector-python 15
# find 15
# socketserver 15
# feedparser 15
# stream 15
# py2neo 15
# timezone 15
# palindrome 15
# abstract-class 15
# pyopenssl 15
# binance 15
# hadoop-streaming 15
# http-post 15
# line 15
# compare 15
# webcam 15
# timedelta 14
# menu 14
# rename 14
# visualization 14
# upgrade 14
# twilio 14
# version 14
# argv 14
# expression 14
# main 14
# naivebayes 14
# fft 14
# django-haystack 14
# pytz 14
# mergesort 14
# vtk 14
# buffer 14
# type-hinting 14
# plone 14
# ide 14
# spark-dataframe 14
# trigonometry 14
# mutable 14
# collections 14
# scala 14
# shapely 14
# pytables 14
# pynput 14
# circular-dependency 14
# pattern-matching 14
# os.path 14
# equality 14
# telethon 14
# pyspark-sql 14
# token 14
# multiplication 14
# bluetooth 14
# size 14
# data-mining 14
# pyyaml 14
# curses 14
# listbox 14
# ms-access 14
# opencv-python 14
# f2py 14
# xlsx 14
# svn 14
# airflow-scheduler 14
# mercurial 14
# kivymd 14
# sage 14
# python-social-auth 14
# python-internals 14
# pyopengl 14
# deep-copy 14
# pytube 14
# autoencoder 13
# grid-search 13
# matplotlib-basemap 13
# openshift 13
# kafka-python 13
# requirements.txt 13
# code-coverage 13
# memcached 13
# match 13
# scipy-optimize 13
# abaqus 13
# normalization 13
# vectorization 13
# environment 13
# one-hot-encoding 13
# openai-gym 13
# uninstallation 13
# crash 13
# scheduler 13
# timeit 13
# collision-detection 13
# google-app-engine-python 13
# backtracking 13
# continue 13
# frequency 13
# correlation 13
# tensorflow-lite 13
# pass-by-reference 13
# openerp-7 13
# filesystems 13
# css-selectors 13
# metaclass 13
# wagtail 13
# class-method 13
# python-jira 13
# async-await 13
# youtube 13
# ode 13
# text-processing 13
# export-to-csv 13
# call 13
# django-serializer 13
# virtualenvwrapper 13
# port 13
# qthread 13
# profiling 13
# named-entity-recognition 13
# atom-editor 13
# google-cloud-firestore 13
# bert-language-model 13
# tic-tac-toe 13
# db2 13
# google-oauth 13
# dask-distributed 13
# praw 13
# stringio 13
# class-variables 13
# response 13
# browser 13
# train-test-split 13
# overflow 13
# celerybeat 13
# object-detection-api 13
# aws-glue 13
# qt4 13
# python-wheel 13
# computer-science 12
# patch 12
# contextmanager 12
# binaryfiles 12
# frame 12
# callable 12
# centos7 12
# zsh 12
# python-c-extension 12
# http-status-code-404 12
# pivot-table 12
# snakemake 12
# minidom 12
# xlwt 12
# python-poetry 12
# django-allauth 12
# transactions 12
# pathlib 12
# scatter-plot 12
# config 12
# coverage.py 12
# ray 12
# data-visualization 12
# reddit 12
# folium 12
# azure-functions 12
# qgis 12
# threadpool 12
# telnet 12
# file-permissions 12
# simpy 12
# hdfs 12
# wav 12
# immutability 12
# wrapper 12
# xml-rpc 12
# command-prompt 12
# csrf 12
# qt-designer 12
# rnn 12
# django-2.0 12
# blit 12
# go 12
# hashlib 12
# ghostscript 12
# thread-safety 12
# repr 12
# mpi 12
# resize 12
# keyword 11
# amazon-rds 11
# migrate 11
# cuda 11
# slack-api 11
# feature-extraction 11
# alembic 11
# snmp 11
# scrollbar 11
# header 11
# ethereum 11
# locking 11
# pygobject 11
# blobstore 11
# convolution 11
# hyperparameters 11
# django-users 11
# logical-operators 11
# f-string 11
# sublimetext 11
# vlc 11
# blocking 11
# signal-processing 11
# intellij-idea 11
# wsdl 11
# python-zipfile 11
# python-dateutil 11
# locale 11
# bitwise-operators 11
# hbase 11
# internationalization 11
# space-complexity 11
# django-database 11
# python-pptx 11
# zope 11
# settings 11
# distance 11
# web3 11
# psutil 11
# client-server 11
# httplib2 11
# map 11
# system 11
# jpeg 11
# pyparsing 11
# jpype 11
# minimize 11
# cvxpy 11
# model-view-controller 11
# connection 11
# snowflake-cloud-data-platform 11
# gil 11
# interface 11
# fibonacci 11
# pydub 11
# svg 11
# firebase-realtime-database 11
# registry 11
# google-cloud-pubsub 11
# virtual-environment 11
# video-capture 11
# yolo 11
# interactive 11
# nohup 11
# stanford-nlp 11
# swagger 11
# radio-button 11
# lda 11
# nosql 11
# local-variables 11
# fedora 11
# vscode-settings 11
# text-to-speech 11
# finance 10
# salt-stack 10
# pygame-surface 10
# pybrain 10
# synchronization 10
# multiple-columns 10
# sublimetext2 10
# mathematical-optimization 10
# database-migration 10
# message 10
# cluster-computing 10
# annotations 10
# midi 10
# stored-procedures 10
# localhost 10
# shebang 10
# stderr 10
# thrift 10
# vpython 10
# draw 10
# shuffle 10
# euclidean-distance 10
# pagination 10
# postman 10
# travis-ci 10
# powerpoint 10
# qt5 10
# cpu 10
# oracle11g 10
# werkzeug 10
# django-signals 10
# celery-task 10
# pyqtgraph 10
# amazon-emr 10
# iterable-unpacking 10
# floating-accuracy 10
# median 10
# matrix-multiplication 10
# local 10
# numeric 10
# amazon-sqs 10
# comparison-operators 10
# coordinates 10
# combobox 10
# static-methods 10
# treeview 10
# min 10
# psychopy 10
# imagemagick 10
# ubuntu-12.04 10
# backpropagation 10
# httplib 10
# mysql-connector 10
# flake8 10
# permission-denied 10
# load 10
# except 10
# restructuredtext 10
# vagrant 10
# pyopencl 10
# packet-sniffers 10
# breadth-first-search 10
# png 10
# casting 10
# mako 10
# whitespace 10
# temporary-files 10
# embedding 10
# chatterbot 10
# configparser 10
# mapping 10
# caesar-cipher 10
# descriptor 10
# middleware 10
# metaprogramming 10
# operator-overloading 10
# pybind11 10
# popup 10
# root 10
# del 10
# comments 10
# grpc-python 10
# chat 10
# nosetests 10
# pyobjc 10
# similarity 10
# singleton 10
# tflearn 10
# cs50 10
# gps 10
# uppercase 10
# overloading 10
# database-connection 10
# fork 10
# naming-conventions 10
# xor 10
# micropython 10
# introspection 10
# tcl 10
# eof 10
# ms-word 10
# getattr 10
# egg 10
# couchdb 10
# django-1.8 10
# physics 10
# idioms 10
# doctest 10
# odoo-14 10
# web-deployment 10
# uuid 10
# tableau-api 10
# http-headers 10
# telnetlib 10
# face-detection 10
# slurm 9
# or-tools 9
# apple-m1 9
# dice 9
# ipc 9
# calendar 9
# iot 9
# abstract-syntax-tree 9
# windows-subsystem-for-linux 9
# usb 9
# streaming 9
# modulenotfounderror 9
# sudoku 9
# pyttsx 9
# autobahn 9
# special-characters 9
# eventlet 9
# packaging 9
# netcdf4 9
# categorical-data 9
# streamlit 9
# formset 9
# python-extensions 9
# python-typing 9
# windows-xp 9
# eoferror 9
# virtual-machine 9
# execution 9
# monkeypatching 9
# softmax 9
# python-embedding 9
# array-broadcasting 9
# python-webbrowser 9
# zlib 9
# feature-selection 9
# refresh 9
# spss 9
# mean 9
# gimp 9
# q-learning 9
# plotly-python 9
# google-cloud-datalab 9
# vue.js 9
# python-2.5 9
# redhat 9
# osx-lion 9
# linux-mint 9
# odoo-12 9
# arcpy 9
# sh 9
# charts 9
# eve 9
# geocoding 9
# event-handling 9
# simplejson 9
# arcgis 9
# architecture 9
# manytomanyfield 9
# continuous-integration 9
# lookup 9
# delimiter 9
# multilabel-classification 9
# doc2vec 9
# hyperlink 9
# glade 9
# django-2.1 9
# bloomberg 9
# gcloud 9
# django-registration 9
# python.net 9
# shallow-copy 9
# containers 9
# fasttext 9
# eigenvector 9
# xmlhttprequest 9
# pysftp 9
# swap 9
# hashtable 9
# defaultdict 9
# publish-subscribe 9
# complexity-theory 9
# minimax 9
# m2crypto 9
# updates 9
# data-cleaning 9
# transfer-learning 9
# random-seed 9
# shelve 9
# cursor 9
# osx-mavericks 9
# signals-slots 9
# indexoutofrangeexception 9
# google-sheets 9
# multiline 9
# plugins 9
# httpresponse 9
# pyhook 8
# class-attributes 8
# multiprocess 8
# gaussian 8
# oracle-sqldeveloper 8
# rasa-core 8
# solr 8
# background 8
# avro 8
# stripe-payments 8
# odoo-11 8
# flask-migrate 8
# graphql 8
# alexa 8
# frameworks 8
# unique 8
# bayesian 8
# keylogger 8
# rasa-nlu 8
# compiler-construction 8
# binding 8
# quandl 8
# findall 8
# python-cryptography 8
# display 8
# notepad++ 8
# nvidia 8
# default 8
# wait 8
# email-attachments 8
# pivot 8
# keyboardinterrupt 8
# postgis 8
# relative-path 8
# youtube-api 8
# h2o 8
# undefined 8
# windows-services 8
# gridsearchcv 8
# subtraction 8
# session-cookies 8
# youtube-dl 8
# rhel 8
# chess 8
# pymupdf 8
# etl 8
# scons 8
# odoo-9 8
# extend 8
# twython 8
# text-mining 8
# 2d 8
# quotes 8
# docx 8
# factorial 8
# structure 8
# next 8
# forecasting 8
# distribute 8
# django-1.4 8
# django-filter 8
# virtualbox 8
# field 8
# certificate 8
# heatmap 8
# osx-snow-leopard 8
# simplehttpserver 8
# makemigrations 8
# instantiation 8
# osx-elcapitan 8
# strptime 8
# gitpython 8
# yahoo-finance 8
# character 8
# tdd 8
# systemd 8
# deadlock 8
# happybase 8
# modbus 8
# joblib 8
# led 8
# args 8
# layout 8
# github-api 8
# nonblocking 8
# mpi4py 8
# jira-rest-api 8
# instagram-api 8
# pdfminer 8
# routes 8
# iframe 8
# geospatial 8
# dbscan 8
# declaration 8
# service 8
# polymorphism 8
# database-design 8
# kill 8
# mime 8
# x11 8
# iis 8
# task 8
# pydoc 8
# cors 8
# openstack 8
# quantitative-finance 8
# cloud 8
# cosine-similarity 8
# linker 8
# inspect 8
# schedule 8
# string-comparison 8
# toplevel 8
# loss 8
# filtering 8
# libsvm 8
# graph-tool 8
# filepath 8
# translation 8
# bubble-sort 8
# graphlab 8
# jwt 8
# control-flow 8
# trading 8
# rss 7
# binary-data 7
# grouping 7
# a-star 7
# opencl 7
# ptvs 7
# errno 7
# cypher 7
# slack 7
# dataflow 7
# 32bit-64bit 7
# pypdf 7
# dom 7
# element 7
# subclassing 7
# lldb 7
# subset 7
# python-hypothesis 7
# definition 7
# lightgbm 7
# geojson 7
# teradata 7
# numerical-methods 7
# django-1.11 7
# tfrecord 7
# speech-to-text 7
# gnupg 7
# generator-expression 7
# alpine 7
# tox 7
# mask 7
# jaydebeapi 7
# splinter 7
# genetic-algorithm 7
# bind 7
# nested-function 7
# pycryptodome 7
# progress-bar 7
# line-breaks 7
# instance-variables 7
# decoding 7
# bytecode 7
# rows 7
# full-text-search 7
# gdata 7
# pandas-datareader 7
# icons 7
# xbee 7
# tfidfvectorizer 7
# py-telegram-bot-api 7
# pong 7
# equation 7
# mrjob 7
# cntk 7
# pymc 7
# pyperclip 7
# tiff 7
# long-integer 7
# pcap 7
# wget 7
# language-agnostic 7
# lazy-evaluation 7
# amazon-iam 7
# click 7
# key-value 7
# scroll 7
# webkit 7
# mp3 7
# bounding-box 7
# pyc 7
# dialogflow-es 7
# azure-sql-database 7
# nao-robot 7
# mechanize-python 7
# c++11 7
# solidity 7
# macports 7
# gettext 7
# file-transfer 7
# higher-order-functions 7
# interactive-brokers 7
# upload 7
# python-2.4 7
# stomp 7
# standard-deviation 7
# image-classification 7
# switch-statement 7
# cprofile 7
# constants 7
# marshmallow 7
# shortest-path 7
# aws-api-gateway 7
# qpython 7
# taskscheduler 7
# azure-blob-storage 7
# subdirectory 7
# frame-rate 7
# diff 7
# sha256 7
# tar 7
# getter-setter 7
# intersection 7
# pymongo-3.x 7
# reload 7
# google-cloud-sql 7
# buildout 7
# transpose 7
# concat 7
# boolean-expression 7
# http-status-code-403 7
# nodes 7
# cartopy 7
# django-import-export 7
# shapes 7
# vb.net 7
# function-call 7
# gmail-api 7
# dictionary-comprehension 7
# spotify 7
# astropy 7
# google-compute-engine 7
# cairo 7
# distributed-computing 7
# anaconda3 7
# conventions 7
# macos-catalina 7
# strftime 7
# least-squares 7
# word-cloud 7
# confusion-matrix 7
# django-csrf 7
# recv 7
# image-segmentation 7
# send 7
# zero 7
# django-tests 7
# ping 7
# adafruit 7
# fuzzywuzzy 7
# rotation 7
# torchvision 7
# django-middleware 7
# haskell 7
# asterisk 7
# tor 7
# difference 7
# xmlrpclib 7
# pi 7
# python-3.10 7
# generative-adversarial-network 7
# lua 7
# impala 7
# literals 7
# wave 7
# setattr 7
# octave 7
# project 7
# gradient 7
# graph-algorithm 7
# imread 7
# bdd 7
# lowercase 7
# task-queue 7
# rasa 7
# dijkstra 7
# cudnn 7
# map-function 7
# amqp 7
# panda3d 7
# flask-mail 7
# google-maps 7
# django-generic-views 7
# azure-databricks 7
# pypyodbc 7
# django-cors-headers 7
# backslash 7
# xampp 7
# paypal 7
# hashmap 7
# predict 7
# geodjango 7
# minecraft 6
# python-3.2 6
# readfile 6
# ubuntu-20.04 6
# tqdm 6
# sha 6
# web3py 6
# punctuation 6
# brownie 6
# yfinance 6
# simplecv 6
# read-write 6
# python-playsound 6
# catboost 6
# blockchain 6
# asyncpg 6
# yum 6
# uvicorn 6
# bootstrap-4 6
# windows-7-x64 6
# bs4 6
# superclass 6
# elasticsearch-dsl 6
# dropbox 6
# admin 6
# multiclass-classification 6
# tensorflow-probability 6
# configuration-files 6
# delay 6
# python-socketio 6
# event-loop 6
# freebsd 6
# codec 6
# amazon-ecs 6
# coreml 6
# location 6
# markdown 6
# pyro 6
# maven 6
# amazon-athena 6
# views 6
# tensorflow-serving 6
# pyarrow 6
# easygui 6
# gql 6
# cupy 6
# mouse 6
# text-parsing 6
# tweets 6
# fixtures 6
# ternary-operator 6
# archlinux 6
# ordereddictionary 6
# dask-dataframe 6
# sigmoid 6
# tensorflow-estimator 6
# 64-bit 6
# raspberry-pi4 6
# double-quotes 6
# report 6
# benchmarking 6
# hmac 6
# dqn 6
# osx-mountain-lion 6
# aptana 6
# z3 6
# protocols 6
# active-directory 6
# ram 6
# sonarqube 6
# scatter 6
# priority-queue 6
# pyenchant 6
# pyobject 6
# gmail-imap 6
# python-appium 6
# wildcard 6
# pyephem 6
# selenium2library 6
# posix 6
# combinatorics 6
# shortcut 6
# evaluation 6
# listdir 6
# splunk 6
# row 6
# luigi 6
# service-accounts 6
# translate 6
# memory-address 6
# ipywidgets 6
# anagram 6
# pydot 6
# arduino-uno 6
# modulus 6
# comma 6
# sieve-of-eratosthenes 6
# asyncore 6
# linkedin 6
# mxnet 6
# char 6
# wpf 6
# exif 6
# pymel 6
# montecarlo 6
# sniffing 6
# large-files 6
# operation 6
# storage 6
# mamp 6
# imagefield 6
# tabs 6
# rpm 6
# notifications 6
# move 6
# cloud9-ide 6
# jdbc 6
# ubuntu-10.04 6
# cqlsh 6
# gitlab 6
# outliers 6
# solver 6
# rgb 6
# web-development-server 6
# indexoutofboundsexception 6
# remote-access 6
# differential-equations 6
# lines 6
# static-files 6
# ansible-playbook 6
# roc 6
# mongodb-query 6
# openerp-8 6
# rpc 6
# heap 6
# cisco 6
# microsoft-cognitive 6
# insertion-sort 6
# git-submodules 6
# image-recognition 6
# pycairo 6
# geolocation 6
# string-matching 6
# lighttpd 6
# photoimage 6
# dill 6
# checkbox 6
# sendmail 6
# digital-ocean 6
# shapefile 6
# pysvn 6
# rrdtool 6
# pyjnius 6
# pdf-generation 6
# devops 6
# messagebox 6
# digits 6
# vgg-net 6
# psycopg 6
# axios 6
# typing 6
# ldap3 6
# sift 6
# pandas-profiling 6
# python-sounddevice 6
# put 6
# cpu-usage 6
# wlst 6
# data-processing 6
# sikuli 6
# cvxopt 6
# relationship 6
# textbox 6
# twine 6
# grep 6
# file-writing 6
# countvectorizer 6
# basehttpserver 6
# qtablewidget 6
# polygon 6
# ibm-cloud 6
# namedtuple 6
# counting 6
# pygithub 6
# django-nonrel 6
# tabula 6
# string-concatenation 6
# arima 6
# xvfb 5
# missing-data 5
# glpk 5
# rethinkdb 5
# aws-cdk 5
# mlp 5
# connector 5
# i2c 5
# bson 5
# dynamodb-queries 5
# tensorflow-gpu 5
# celeryd 5
# utf 5
# blpapi 5
# dialog 5
# fetch 5
# amazon-cloudformation 5
# batch-processing 5
# blob 5
# vmware 5
# markov-chains 5
# smartsheet-api 5
# azure-machine-learning-service 5
# laravel 5
# wifi 5
# cron-task 5
# left-join 5
# simpleitk 5
# voice-recognition 5
# camera-calibration 5
# base 5
# pythoninterpreter 5
# django-1.9 5
# integer-overflow 5
# mayavi 5
# imbalanced-data 5
# monkeyrunner 5
# object-oriented-analysis 5
# getch 5
# cloudera 5
# flatten 5
# locust 5
# oct2py 5
# auc 5
# django-custom-user 5
# credentials 5
# jsonschema 5
# macos-big-sur 5
# graphene-python 5
# eigenvalue 5
# polynomials 5
# instapy 5
# zappa 5
# qml 5
# microphone 5
# pandas-to-sql 5
# constraints 5
# minimization 5
# odoo-13 5
# python-cffi 5
# html-table 5
# apt 5
# rolling-computation 5
# six 5
# qpython3 5
# visa 5
# emr 5
# paraview 5
# python-twitter 5
# clock 5
# github3.py 5
# robot 5
# complex-numbers 5
# argument-unpacking 5
# access-denied 5
# onclick 5
# firebase-admin 5
# django-rest-viewsets 5
# rs485 5
# gobject-introspection 5
# frontend 5
# visual-c++ 5
# operator-keyword 5
# screen 5
# crc32 5
# resnet 5
# recommendation-engine 5
# sublist 5
# analytics 5
# scoring 5
# background-process 5
# calculation 5
# substitution 5
# selenium-firefoxdriver 5
# imgur 5
# nvidia-jetson 5
# remote-debugging 5
# alexa-skills-kit 5
# execute 5
# wireshark 5
# stock 5
# keypress 5
# helper 5
# webhooks 5
# maze 5
# confluent-platform 5
# pretty-print 5
# video-processing 5
# drop-down-menu 5
# macos-mojave 5
# registration 5
# brython 5
# exchangelib 5
# macos-sierra 5
# shared-memory 5
# jenkins-pipeline 5
# fetchall 5
# twitter-bootstrap 5
# sieve 5
# startup 5
# contains 5
# ibm-watson 5
# qtcore 5
# ini 5
# zigbee 5
# data-manipulation 5
# mezzanine 5
# http-redirect 5
# named-pipes 5
# increment 5
# gitlab-ci 5
# datastax 5
# agi 5
# gnuradio 5
# gremlin 5
# directory-structure 5
# django-1.6 5
# factory-boy 5
# tix 5
# topic-modeling 5
# python-requests-html 5
# apache-spark-mllib 5
# label-encoding 5
# processbuilder 5
# file-read 5
# vscode-debugger 5
# opencv4 5
# visual-studio-2013 5
# sublimerepl 5
# divide-by-zero 5
# pyrebase 5
# twisted.web 5
# npm 5
# loading 5
# connexion 5
# android-studio 5
# uart 5
# alphabetical 5
# tensorflow-hub 5
# kafka-consumer-api 5
# pyvisa 5
# google-translate 5
# datatable 5
# exchange-server 5
# arabic 5
# brute-force 5
# carriage-return 5
# anomaly-detection 5
# zeep 5
# overwrite 5
# worker 5
# cythonize 5
# geopy 5
# revit-api 5
# pandas-styles 5
# mininet 5
# python-fu 5
# aggregate 5
# pep 5
# information-retrieval 5
# fast-ai 5
# raster 5
# data-fitting 5
# hana 5
# python-ggplot 5
# google-sheets-api 5
# resampling 5
# bytearray 5
# mediawiki 5
# crop 5
# launchd 5
# flash 5
# race-condition 5
# readlines 5
# code-generation 5
# pythoncom 5
# pyusb 5
# unix-timestamp 5
# pyd 5
# unixodbc 5
# perforce 5
# svd 5
# semantics 5
# embed 5
# utc 5
# drag-and-drop 5
# optparse 5
# glibc 5
# logarithm 5
# fractals 5
# python-2to3 5
# deque 5
# sha1 5
# clr 5
# newtons-method 5
# qgraphicsview 5
# default-value 5
# url-routing 5
# objective-c 5
# selenium-rc 5
# pygraphviz 5
# getopt 5
# filedialog 5
# themes 5
# opensuse 5
# httpserver 5
# astronomy 5
# pysqlite 5
# serversocket 5
# init.d 5
# delete-file 5
# preprocessor 5
# include 5
# urlfetch 5
# memoization 5
# random-sample 5
# countdown 5
# equation-solving 5
# arraylist 5
# hook 5
# django-email 5
# dynamic-language-runtime 5
# profile 5
# gobject 5
# packet 5
# paster 5
# asp.net 5
# internet-explorer 5
# freetds 5
# timing 5
# whoosh 5
# ply 5
# mingw 5
# echo 5
# attr 5
# controls 5
# restart 5
# wamp 5
# httpclient 5
# python-sip 5
# trace 5
# undefined-symbol 5
# computational-geometry 5
# django-sessions 5
# libxml2 5
# divide 5
# applescript 5
# virtualhost 5
# wordpress 5
# traversal 5
# drawing 5
# regex-group 5
# qwebview 5
# persistence 5
# mixins 5
# platypus 5
# python-db-api 5
# word 5
# fastcgi 5
# fwrite 5
# pyscripter 5
# wkhtmltopdf 5
# e-commerce 5
# infinite 5
# implementation 5
# distribution 5
# contour 4
# ip-camera 4
# highcharts 4
# ethernet 4
# ibpy 4
# url-pattern 4
# libvlc 4
# python-importlib 4
# failed-installation 4
# swift 4
# flush 4
# dependency-injection 4
# elasticsearch-py 4
# google-chrome-headless 4
# jes 4
# pyhive 4
# simplexmlrpcserver 4
# aerospike 4
# sequential 4
# k-fold 4
# redis-py 4
# azure-web-app-service 4
# django-syncdb 4
# cassandra-3.0 4
# operationalerror 4
# template-engine 4
# apache-nifi 4
# coremltools 4
# urlencode 4
# ncurses 4
# mesh 4
# choice 4
# width 4
# glsl 4
# pyalgotrade 4
# any 4
# sha512 4
# aws-cli 4
# django-deployment 4
# confluent-kafka-python 4
# documentation 4
# python-stackless 4
# io-redirection 4
# python-nonlocal 4
# openstack-nova 4
# editor 4
# cgi-bin 4
# audio-streaming 4
# dataloader 4
# google-ads-api 4
# formula 4
# mlflow 4
# waitress 4
# botocore 4
# datastore 4
# mitmproxy 4
# csh 4
# blackjack 4
# tensorflow2.x 4
# modal-dialog 4
# python-rq 4
# deserialization 4
# lib 4
# jit 4
# imshow 4
# qweb 4
# django-contenttypes 4
# wsgiref 4
# project-structure 4
# render 4
# django-1.5 4
# shap 4
# urlparse 4
# media 4
# submit 4
# technical-indicator 4
# dot-product 4
# assign 4
# quoting 4
# ta-lib 4
# unsupervised-learning 4
# tshark 4
# django-socialauth 4
# scale 4
# supervised-learning 4
# fasta 4
# singly-linked-list 4
# symbols 4
# statusbar 4
# modulo 4
# ibm-cloud-infrastructure 4
# scoping 4
# writer 4
# activemq 4
# attachment 4
# hebrew 4
# binance-api-client 4
# web-frameworks 4
# sentry 4
# hide 4
# centos6 4
# for-in-loop 4
# sharepoint 4
# rdd 4
# mindstorms 4
# antlr4 4
# sniffer 4
# bitcoin 4
# discrete-mathematics 4
# alsa 4
# wordnet 4
# chaco 4
# ipv6 4
# clipboard 4
# g++ 4
# scikits 4
# xslt 4
# pycaffe 4
# voice 4
# salesforce 4
# angular 4
# directed-acyclic-graphs 4
# aws-cloud9 4
# tree-traversal 4
# python-object 4
# textblob 4
# converter 4
# spark-streaming 4
# chef-infra 4
# ui-automation 4
# difflib 4
# zodb 4
# arm 4
# point-clouds 4
# text-based 4
# electron 4
# position 4
# duck-typing 4
# kill-process 4
# var 4
# scipy-optimize-minimize 4
# xmpp 4
# parent-child 4
# foreign-key-relationship 4
# prompt 4
# flask-mongoengine 4
# chunking 4
# amazon-cloudwatch 4
# joystick 4
# iostream 4
# subplot 4
# letters 4
# aggregation 4
# analysis 4
# semantic-segmentation 4
# office365 4
# communication 4
# export-to-excel 4
# bulkloader 4
# boot 4
# textures 4
# mixer 4
# soaplib 4
# filesize 4
# key-value-store 4
# prime-factoring 4
# pocketsphinx 4
# sensors 4
# hierarchy 4
# pandoc 4
# pybluez 4
# kotlin 4
# spotfire 4
# isinstance 4
# number-formatting 4
# exponent 4
# python-curses 4
# choregraphe 4
# flask-restplus 4
# reactor 4
# google-cloud-vision 4
# lan 4
# pid 4
# dry 4
# androidviewclient 4
# stat 4
# django-media 4
# dashboard 4
# epoch 4
# graphml 4
# py4j 4
# serverless-framework 4
# disassembly 4
# matching 4
# poker 4
# scaling 4
# gtts 4
# serial-communication 4
# yocto 4
# chromium 4
# communicate 4
# odeint 4
# pymc3 4
# binning 4
# fractions 4
# pdftotext 4
# shopify 4
# adventure 4
# embedded-linux 4
# padding 4
# syslog 4
# smartcontracts 4
# rdkit 4
# weblogic 4
# auto-increment 4
# method-resolution-order 4
# sanic 4
# quadratic 4
# firebird 4
# perceptron 4
# symbolic-math 4
# qtableview 4
# openid 4
# gpgpu 4
# non-deterministic 4
# libcurl 4
# tcsh 4
# cjk 4
# python-interactive 4
# revitpythonshell 4
# pyrevit 4
# code-completion 4
# python-mode 4
# querying 4
# new-operator 4
# boolean-logic 4
# pysimplegui 4
# julia 4
# one-to-many 4
# qt-creator 4
# pycuda 4
# bigtable 4
# shutdown 4
# localization 4
# styles 4
# tetris 4
# django-cron 4
# dnspython 4
# time-limiting 4
# n-gram 4
# quantlib 4
# focus 4
# iso-8859-1 4
# xls 4
# drake 4
# google-speech-api 4
# google-cloud-composer 4
# import-from-excel 4
# real-time 4
# endianness 4
# recommender-systems 4
# wikipedia 4
# game-development 4
# finally 4
# operand 4
# ipython-parallel 4
# cookiecutter-django 4
# audio-recording 4
# pty 4
# dtype 4
# read-eval-print-loop 4
# word-count 4
# pycord 4
# django-debug-toolbar 4
# selection-sort 4
# stemming 4
# child-process 4
# integration 4
# tkinter-scale 4
# django-file-upload 4
# clang 4
# twitter-oauth 4
# hough-transform 4
# mutability 4
# stack-trace 4
# ip-address 4
# string-to-datetime 4
# libvirt 4
# lisp 4
# ggplot2 4
# stop-words 4
# cross-platform 4
# informix 4
# django-unittest 4
# darknet 4
# spoofing 4
# processing 4
# tsql 4
# geany 4
# selection 4
# elements 4
# falconframework 4
# push 4
# amazon-route53 4
# audio-player 4
# python-ldap 4
# xml.etree 4
# lasagne 4
# cumulative-sum 4
# google-calendar-api 4
# osx-yosemite 4
# cd 4
# upstart 4
# authorization 4
# batch-normalization 4
# seek 4
# google-cloud-python 4
# linux-kernel 4
# express 4
# destructor 4
# sql-server-2008 4
# django-storage 4
# pvlib 4
# broadcast 4
# djongo 4
# sdk 4
# operands 4
# urlconf 4
# magic-methods 4
# google-analytics 4
# pathos 4
# django-mptt 4
# message-queue 4
# doubly-linked-list 4
# fifo 4
# twitter-streaming-api 4
# unicode-string 4
# macros 4
# quickfix 4
# django-manage.py 4
# data-modeling 4
# linq 4
# unity3d 4
# django-1.10 4
# connect 4
# gmpy 4
# representation 4
# text-extraction 4
# amazon-neptune 4
# space 4
# bazel 4
# wing-ide 4
# wand 4
# sendgrid 4
# regex-greedy 4
# functools 4
# passlib 4
# bcrypt 4
# path-finding 4
# routing 4
# game-physics 4
# integrate 4
# relu 4
# holoviews 4
# gimpfu 4
# nmap 4
# urlopen 4
# imblearn 4
# relational-database 4
# pre-trained-model 4
# repeat 4
# textmate 4
# fillna 4
# scrapinghub 4
# file-rename 4
# gherkin 4
# django-1.7 4
# glib 4
# reverse-proxy 4
# mallet 4
# tail-recursion 4
# dllimport 4
# data-augmentation 4
# influxdb 4
# influxdb-python 4
# django-rest-auth 4
# ffprobe 4
# double 4
# pos-tagger 4
# facebook-prophet 4
# conditional-formatting 4
# libraries 4
# pytest-cov 4
# unzip 4
# read-the-docs 4
# multi-index 4
# visual-studio-2015 4
# wmi 4
# drop 3
# vehicle-routing 3
# string-length 3
# exists 3
# mapper 3
# theory 3
# winreg 3
# xlsm 3
# django-paypal 3
# operator-precedence 3
# mkdir 3
# openoffice.org 3
# dronekit-python 3
# readability 3
# parallel-python 3
# abstract-methods 3
# visual-studio-2019 3
# mysql-workbench 3
# django-wsgi 3
# mpmath 3
# eclipse-plugin 3
# pafy 3
# dhcp 3
# parse-platform 3
# djangoappengine 3
# django-q 3
# msbuild 3
# p2p 3
# rank 3
# conda-forge 3
# fullscreen 3
# django-autocomplete-light 3
# jar 3
# version-control 3
# aws-sdk 3
# autoit 3
# logstash 3
# constraint-programming 3
# interactive-mode 3
# porting 3
# lasso-regression 3
# ontology 3
# getattribute 3
# servo 3
# eol 3
# pandas-resample 3
# epydoc 3
# twisted.internet 3
# file-not-found 3
# image-uploading 3
# semaphore 3
# image-resizing 3
# weka 3
# paste 3
# history 3
# memory-efficient 3
# ubuntu-13.10 3
# optional-parameters 3
# alias 3
# chi-squared 3
# radians 3
# data-preprocessing 3
# fizzbuzz 3
# intervals 3
# openldap 3
# file-copying 3
# android-ndk 3
# blogs 3
# repository 3
# exponentiation 3
# renpy 3
# xlutils 3
# bit-shift 3
# boxplot 3
# itk 3
# compiled 3
# captcha 3
# browsermob-proxy 3
# pydrive 3
# terraform 3
# probability-density 3
# error-logging 3
# question-answering 3
# socks 3
# pyelasticsearch 3
# serverless 3
# tcpserver 3
# graphite 3
# sampling 3
# alignment 3
# fuzzy-search 3
# ccxt 3
# linter 3
# dna-sequence 3
# aws-ec2 3
# gfortran 3
# riak 3
# filemaker 3
# cassandra-2.0 3
# winforms 3
# hadoop-yarn 3
# software-distribution 3
# fiona 3
# foreach 3
# store 3
# vaex 3
# microcontroller 3
# autodoc 3
# google-admin-sdk 3
# flask-admin 3
# delaunay 3
# extends 3
# amazon 3
# esp32 3
# naming 3
# excel-formula 3
# cloudant 3
# variable-declaration 3
# accumulator 3
# termux 3
# static-variables 3
# osx-leopard 3
# goto 3
# execfile 3
# hosting 3
# stata 3
# data-transfer 3
# chr 3
# py-postgresql 3
# openstreetmap 3
# sorted 3
# jenkins-plugins 3
# zombie-process 3
# membership 3
# assistant 3
# enumeration 3
# nearest-neighbor 3
# member 3
# connection-pooling 3
# device 3
# root-framework 3
# pyroot 3
# libusb 3
# apple-silicon 3
# vpn 3
# relative-import 3
# private-key 3
# openmdao 3
# gstreamer-1.0 3
# devstack 3
# django-formwizard 3
# pixel 3
# qcombobox 3
# programming-languages 3
# pdfkit 3
# query-optimization 3
# openerp-6 3
# dummy-variable 3
# imagemagick-convert 3
# fernet 3
# port-scanning 3
# jq 3
# monitoring 3
# siamese-network 3
# integration-testing 3
# dask-ml 3
# derivative 3
# pie-chart 3
# bitmap 3
# buildbot 3
# pyshark 3
# azure-machine-learning-studio 3
# delphi 3
# tail 3
# powerpc 3
# beaker 3
# key-bindings 3
# optuna 3
# angle 3
# scalability 3
# cpanel 3
# identity 3
# psexec 3
# multipartform-data 3
# metadata 3
# zipline 3
# jedi 3
# allure 3
# wizard 3
# recursive-backtracking 3
# ruamel.yaml 3
# netfilter 3
# fopen 3
# pde 3
# cplex 3
# jedi-vim 3
# python-dataclasses 3
# deprecation-warning 3
# threadpoolexecutor 3
# youtube-data-api 3
# progress 3
# testcase 3
# genfromtxt 3
# bitbake 3
# minio 3
# aws-lambda-layers 3
# kali-linux 3
# levenshtein-distance 3
# assignment-operator 3
# maya-api 3
# rdflib 3
# mel 3
# updating 3
# sybase 3
# yolov5 3
# jetbrains-ide 3
# rethinkdb-python 3
# gtktreeview 3
# gremlinpython 3
# fipy 3
# colander 3
# transition 3
# qt-signals 3
# assembly 3
# deb 3
# gethostbyname 3
# figure 3
# keras-tuner 3
# trac 3
# omxplayer 3
# beagleboneblack 3
# logrotate 3
# cqlengine 3
# ansi 3
# scrapyd 3
# tibco 3
# shared-ptr 3
# side-effects 3
# dispatch 3
# shellcode 3
# tty 3
# flask-security 3
# packets 3
# xlib 3
# modelica 3
# pygears 3
# mosquitto 3
# gsutil 3
# diacritics 3
# pydantic 3
# relationships 3
# gnome 3
# visibility 3
# bulkinsert 3
# ensemble-learning 3
# icmp 3
# kdtree 3
# model-fitting 3
# django-3.0 3
# pyenv-virtualenv 3
# oauth2client 3
# nvidia-jetson-nano 3
# file-descriptor 3
# dropdown 3
# spawn 3
# image-stitching 3
# collectstatic 3
# google-search 3
# jython-2.7 3
# dimensionality-reduction 3
# opencv-drawcontour 3
# rrd 3
# flask-babel 3
# datepicker 3
# addition 3
# items 3
# z3py 3
# chdir 3
# eel 3
# gdb-python 3
# webautomation 3
# django-oscar 3
# repl.it 3
# runpy 3
# object-slicing 3
# integer-division 3
# unity3d-unet 3
# datatables 3
# netmiko 3
# options 3
# vsphere 3
# function-calls 3
# recursive-datastructures 3
# minesweeper 3
# flood-fill 3
# pelican 3
# lxml.html 3
# reverse-engineering 3
# rpyc 3
# covariance 3
# ubuntu-10.10 3
# instance-methods 3
# word-frequency 3
# convergence 3
# poppler 3
# manage.py 3
# tee 3
# data-pipeline 3
# opencv-contour 3
# integral 3
# cryptocurrency 3
# robobrowser 3
# djcelery 3
# headless-browser 3
# toctree 3
# sections 3
# dart 3
# flask-cli 3
# cocoa 3
# ibis 3
# bluetooth-lowenergy 3
# azure-active-directory 3
# pymol 3
# sql-insert 3
# qprocess 3
# language-design 3
# undetected-chromedriver 3
# gqlquery 3
# google-cloud-ml 3
# powerbi 3
# pyngrok 3
# google-authentication 3
# orbital-mechanics 3
# python-logging 3
# menubar 3
# cffi 3
# onelogin 3
# python-imageio 3
# assets 3
# database-cursor 3
# sl4a 3
# staleelementreferenceexception 3
# thonny 3
# hyperopt 3
# sql-update 3
# wfastcgi 3
# atexit 3
# public-key-encryption 3
# django-grappelli 3
# c-api 3
# word-wrap 3
# pygame-clock 3
# rasterio 3
# python-vlc 3
# at-command 3
# lexer 3
# reflection 3
# hasattr 3
# coin-or-cbc 3
# qtwebkit 3
# twilio-api 3
# geth 3
# downsampling 3
# pystan 3
# knights-tour 3
# product 3
# standardized 3
# scientific-notation 3
# pprint 3
# variance 3
# spotipy 3
# osmnx 3
# offline 3
# django-apps 3
# autokey 3
# notepad 3
# kafka-producer-api 3
# solaris 3
# pyppeteer 3
# quart 3
# strace 3
# nagios 3
# sendkeys 3
# slots 3
# psql 3
# pgadmin 3
# yield-keyword 3
# readonly 3
# windows-installer 3
# syntax-highlighting 3
# adb 3
# google-assistant-sdk 3
# flask-session 3
# portaudio 3
# plc 3
# indices 3
# altair 3
# sap-ase 3
# visual-studio-2010 3
# espeak 3
# arp 3
# truncation 3
# chalice 3
# icalendar 3
# pydicom 3
# regex-lookarounds 3
# ckan 3
# multilingual 3
# xhtml2pdf 3
# cmusphinx 3
# dicom 3
# iphone 3
# uvloop 3
# simplify 3
# qpixmap 3
# interrupt 3
# alpha-vantage 3
# tabula-py 3
# bitnami 3
# sms 3
# square 3
# graph-databases 3
# tkinter-layout 3
# ieee-754 3
# chainer 3
# xmlsec 3
# bootstrap-modal 3
# gearman 3
# words 3
# sasl 3
# kombu 3
# dreamhost 3
# msys 3
# callstack 3
# release 3
# delete-row 3
# azure-data-lake 3
# autostart 3
# log4j 3
# rsync 3
# ponyorm 3
# dlopen 3
# macos-high-sierra 3
# splash-screen 3
# natural-language-processing 3
# api-design 3
# amazon-ses 3
# ld 3
# inner-join 3
# piping 3
# external 3
# robotics 3
# json-rpc 3
# openfiledialog 3
# systemctl 3
# mediapipe 3
# inline-formset 3
# keycloak 3
# schema 3
# collision 3
# reticulate 3
# grammar 3
# converters 3
# .htaccess 3
# fastparquet 3
# default-arguments 3
# antlr 3
# ignite 3
# dbf 3
# django-tables2 3
# music21 3
# nuitka 3
# fits 3
# elasticsearch-dsl-py 3
# game-engine 3
# html-email 3
# pack 3
# nextcord 3
# fragment-shader 3
# qgraphicsscene 3
# openvino 3
# intel 3
# site-packages 3
# django-template-filters 3
# appium-android 3
# audio-processing 3
# rollback 3
# splice 3
# pyflakes 3
# scheduling 3
# skype4py 3
# pycassa 3
# kubernetes-python-client 3
# lazy-loading 3
# spline 3
# cisco-ios 3
# system-error 3
# distributed 3
# public-key 3
# cookielib 3
# case-insensitive 3
# qwebengineview 3
# system-calls 3
# django-sphinx 3
# python-elixir 3
# state 3
# requestcontext 3
# rfc 3
# point 3
# argument-passing 3
# kubernetes-helm 3
# octal 3
# puzzle 3
# sumo 3
# amazon-simpledb 3
# truthiness 3
# legend 3
# rstudio 3
# spaces 3
# data-conversion 3
# templatetags 3
# cloud-foundry 3
# autograd 3
# activation-function 3
# recaptcha 3
# numpy-einsum 3
# hudson 3
# tcp-ip 3
# google-mirror-api 3
# consumer 3
# buffer-overflow 3
# floating-point-precision 3
# bidirectional 3
# postgresql-9.5 3
# elementwise-operations 3
# percentile 3
# minimum 3
# lemmatization 3
# git-bash 3
# greenplum 3
# backup 3
# docplex 3
# windowserror 3
# microsoft-graph-api 3
# frequency-analysis 3
# vision 3
# robotframework-ide 3
# apache-zeppelin 3
# kodi 3
# conditional-operator 3
# pytorch-dataloader 3
# favicon 3
# ruby-on-rails 3
# xmpppy 3
# ngrok 3
# tarfile 3
# cookiejar 3
# namespace-package 3
# zapier 3
# pandasql 3
# flask-pymongo 3
# git-diff 3
# instances 3
# gitlab-ci-runner 3
# disable 3
# normalize 3
# apache-tika 3
# stack-overflow 3
# waf 3
# soda 3
# html-parser 3
# partitioning 3
# mcmc 3
# destroy 3
# soappy 3
# prettytable 3
# apache-airflow 3
# channels 3
# poloniex 3
# minikube 3
# weighted-graph 3
# phpmyadmin 3
# spynner 3
# python-mock 3
# pythonbrew 3
# qtablewidgetitem 3
# win32gui 3
# windows-console 3
# standard-library 3
# moving-average 3
# pkcs#11 3
# assertion 2
# common-table-expression 2
# usergroups 2
# csrf-protection 2
# mplayer 2
# feincms 2
# pseudocode 2
# chart.js 2
# google-trends 2
# rasa-x 2
# bounce 2
# kubernetes-ingress 2
# usrp 2
# linear-interpolation 2
# winsound 2
# axis-labels 2
# multicore 2
# flann 2
# imputation 2
# limit 2
# pandas.excelwriter 2
# sendfile 2
# aws-xray 2
# dsl 2
# steganography 2
# mainloop 2
# matlab-engine 2
# centroid 2
# msys2 2
# canoe 2
# foursquare 2
# sparqlwrapper 2
# best-fit-curve 2
# composite 2
# quantlib-swig 2
# user-agent 2
# read.csv 2
# django-timezone 2
# filehandle 2
# crossbar 2
# 32-bit 2
# src 2
# pkcs#7 2
# playback 2
# one-to-one 2
# stride 2
# multipart 2
# amazon-cloudfront 2
# youcompleteme 2
# summarization 2
# newrelic 2
# numpy-slicing 2
# video-tracking 2
# tinydb 2
# primary-key 2
# saleor 2
# declarative 2
# facebook-ads-api 2
# boilerpipe 2
# facebook-marketing-api 2
# coinbase-api 2
# reset 2
# associations 2
# weasyprint 2
# edge-detection 2
# ppm 2
# python-click 2
# nifti 2
# prolog 2
# azure-servicebus-queues 2
# mpld3 2
# stopiteration 2
# custom-exceptions 2
# pageobjects 2
# genome 2
# tagging 2
# mu 2
# manim 2
# access-token 2
# pacman 2
# scraper 2
# collatz 2
# tika-server 2
# django-filer 2
# whitenoise 2
# tcpdump 2
# linecache 2
# database-performance 2
# traitsui 2
# auto-keras 2
# pom.xml 2
# flash-message 2
# amazon-kinesis 2
# sequences 2
# measure 2
# bqplot 2
# atomic 2
# module-packaging 2
# eoserror 2
# reverse-geocoding 2
# django-contrib 2
# asyncsocket 2
# class-design 2
# papermill 2
# trie 2
# uint 2
# inotify 2
# boosting 2
# debian-based 2
# windows-8.1 2
# smote 2
# office365api 2
# ports 2
# exchangewebservices 2
# non-english 2
# portforwarding 2
# units-of-measurement 2
# scipy.ndimage 2
# python-zappa 2
# bzip2 2
# language-translation 2
# blueprint 2
# lsb 2
# flask-jwt-extended 2
# jmodelica 2
# vaticle-typeql 2
# annotate 2
# face 2
# numerical-integration 2
# resolution 2
# weather 2
# forecast 2
# ffi 2
# coredump 2
# app-engine-patch 2
# google-cloud-run 2
# vaticle-typedb 2
# declare 2
# flags 2
# sqrt 2
# in-place 2
# ps 2
# darkflow 2
# xml-namespaces 2
# box 2
# coefficients 2
# mlab 2
# stem 2
# keyboard-events 2
# pylibmc 2
# convolutional-neural-network 2
# industrial 2
# makemessages 2
# sign 2
# colorama 2
# pyspider 2
# datetimeindex 2
# python-zip 2
# non-relational-database 2
# qwidget 2
# file-processing 2
# google-authenticator 2
# flask-cors 2
# gremlin-server 2
# porter-stemmer 2
# code-injection 2
# ddos 2
# transform 2
# google-cloud-shell 2
# flask-ask 2
# csvreader 2
# geoip 2
# street-address 2
# skopt 2
# restore 2
# pywikibot 2
# azure-devops 2
# hdfstore 2
# edges 2
# syntactic-sugar 2
# movefile 2
# action 2
# modbus-tcp 2
# qtmultimedia 2
# multi-gpu 2
# payload 2
# alpha-beta-pruning 2
# esxi 2
# url-parsing 2
# memoryview 2
# sigkill 2
# iris-dataset 2
# cancellation 2
# tls1.2 2
# abstract 2
# flask-bootstrap 2
# internals 2
# arcade 2
# ssh-tunnel 2
# execv 2
# working-directory 2
# overhead 2
# cerberus 2
# shell-exec 2
# hortonworks-data-platform 2
# pm2 2
# nats.io 2
# python-black 2
# netbeans 2
# gdbm 2
# plesk 2
# pythoncard 2
# expression-trees 2
# handler 2
# tabulate 2
# tensorflow-transform 2
# pygments 2
# hamming-distance 2
# qsqlrelationaltablemodel 2
# textinput 2
# amazon-sns 2
# wc 2
# statistical-test 2
# syslog-ng 2
# rfid 2
# disk 2
# lag 2
# alphabet 2
# openmp 2
# multiprocessing-manager 2
# scientific-computing 2
# twitterapi-python 2
# font-size 2
# formalchemy 2
# rar 2
# tkinter-menu 2
# recurrence 2
# tkcalendar 2
# operations 2
# python-camelot 2
# docker-toolbox 2
# panel 2
# live-streaming 2
# stopwatch 2
# greatest-common-divisor 2
# ninja 2
# database-trigger 2
# python-trio 2
# dtw 2
# http-status-code-500 2
# unique-constraint 2
# coin-flipping 2
# lookbehind 2
# record 2
# opencv3.1 2
# featuretools 2
# single-sign-on 2
# poster 2
# workflow 2
# singularity-container 2
# mailgun 2
# qt-quick 2
# azure-data-factory 2
# chunks 2
# markers 2
# google-kubernetes-engine 2
# stackdriver 2
# weighted-average 2
# argmax 2
# rtsp 2
# google-geocoder 2
# nxt-python 2
# superset 2
# pairwise 2
# precision-recall 2
# owlready 2
# n-queens 2
# rdf 2
# procfile 2
# socrata 2
# frames 2
# bitstring 2
# docker-image 2
# qsqldatabase 2
# flow-project 2
# barcode 2
# azure-storage 2
# reader 2
# maximize 2
# sqoop 2
# hosts 2
# unbound 2
# pyfacebook 2
# pg8000 2
# metpy 2
# mat 2
# tab-completion 2
# tomcat 2
# adodbapi 2
# timezone-offset 2
# resources 2
# conda-build 2
# stocktwits 2
# pyathena 2
# bytestream 2
# google-cloud-build 2
# google-crawlers 2
# lmdb 2
# ansible-2.x 2
# visual-studio-2017 2
# cdf 2
# data-science-experience 2
# intel-mkl 2
# expected-condition 2
# python-django-storages 2
# raw-sockets 2
# quantization 2
# ipdb 2
# leaflet 2
# pyasn1 2
# matrix-indexing 2
# gradienttape 2
# state-machine 2
# google-translation-api 2
# google-finance 2
# mbox 2
# geotiff 2
# pychef 2
# out 2
# scandir 2
# query-performance 2
# winscp 2
# kubernetes-pod 2
# google-docs 2
# filenotfoundexception 2
# impyla 2
# cache-control 2
# partials 2
# plist 2
# where-clause 2
# gekko 2
# maemo 2
# x509certificate 2
# toast 2
# cloning 2
# facebook-messenger-bot 2
# dropbox-api 2
# lcd 2
# qlabel 2
# pydal 2
# cyrillic 2
# watson 2
# nonlinear-optimization 2
# pepper 2
# pause 2
# marketo 2
# network-drive 2
# uniform-distribution 2
# kolmogorov-smirnov 2
# azure-eventhub 2
# firebase-cloud-messaging 2
# rhel7 2
# height 2
# mplfinance 2
# bittorrent 2
# unsupportedoperation 2
# django-rest-framework-simplejwt 2
# mongodb-atlas 2
# fbs 2
# datetime-format 2
# python-pex 2
# adaboost 2
# faker 2
# decoder 2
# temp 2
# tinkerpop 2
# plotly.js 2
# desktop 2
# magicmock 2
# spinner 2
# scip 2
# haar-classifier 2
# qtreeview 2
# reduce 2
# aggregation-framework 2
# lapacke 2
# spring-boot 2
# powerset 2
# elf 2
# tikz 2
# circleci 2
# panel-data 2
# django-crispy-forms 2
# pytest-django 2
# flask-oauthlib 2
# scanning 2
# candlestick-chart 2
# terminate 2
# bulk 2
# random-walk 2
# pkcs#1 2
# sliding-window 2
# axis 2
# content-length 2
# abc 2
# inequality 2
# ravendb 2
# windows-10-desktop 2
# cublas 2
# fuzzy 2
# pygame-tick 2
# slim 2
# sphinx 2
# microservices 2
# convex-hull 2
# aiopg 2
# cloud9 2
# one-time-password 2
# burp 2
# google-python-api 2
# stability 2
# ckeditor 2
# apriori 2
# do-while 2
# delayed-execution 2
# matcher 2
# truetype 2
# yahoo-api 2
# shift 2
# mingw-w64 2
# teardown 2
# data-warehouse 2
# elisp 2
# distinct 2
# trim 2
# categories 2
# rescale 2
# msg 2
# non-linear-regression 2
# python-netifaces 2
# haversine 2
# ib-api 2
# python-mss 2
# docker-build 2
# can-bus 2
# code-inspection 2
# int64 2
# azure-sdk-python 2
# ellipsis 2
# windows-server-2003 2
# bspline 2
# cad 2
# libpng 2
# cheetah 2
# detection 2
# backwards-compatibility 2
# couchbase 2
# pycallgraph 2
# app-bundle 2
# encryption-asymmetric 2
# jsonparser 2
# swagger-2.0 2
# oozie 2
# photoshop 2
# language-model 2
# secret-key 2
# ansible-inventory 2
# pinax 2
# svc 2
# xrange 2
# derived-class 2
# where-in 2
# html5lib 2
# lex 2
# beagleboard 2
# network-protocols 2
# automator 2
# bolt 2
# scipy.stats 2
# sonarqube-scan 2
# open-source 2
# sap 2
# apt-get 2
# simpleaudioengine 2
# lint 2
# selenium-iedriver 2
# typescript 2
# aws-codebuild 2
# locked 2
# launch 2
# noise 2
# python-dragonfly 2
# keras-2 2
# eager-execution 2
# file-manipulation 2
# video-streaming 2
# mutation 2
# activepython 2
# wolframalpha 2
# html-input 2
# ipopt 2
# dask-delayed 2
# area 2
# pyuic 2
# border 2
# deferred-execution 2
# apache2.4 2
# gasp 2
# http-proxy 2
# pkg-resources 2
# gdata-api 2
# flask-mysql 2
# pys60 2
# asgi 2
# smoothing 2
# gazebo-simu 2
# tinkerpop3 2
# password-generator 2
# infinite-scroll 2
# django-polymorphic 2
# python-chess 2
# wss 2
# amazon-ecr 2
# emoji 2
# bytesio 2
# biginteger 2
# hug 2
# slider 2
# node-red 2
# uint8t 2
# pentaho 2
# twincat 2
# wavelet 2
# euler-angles 2
# pythonista 2
# multiple-instances 2
# digraphs 2
# artifactory 2
# simpsons-rule 2
# is-empty 2
# mkdocs 2
# ios-simulator 2
# pyral 2
# rally 2
# multicast 2
# interleave 2
# apache-flink 2
# apk 2
# deeplearning4j 2
# std 2
# xss 2
# pytest-xdist 2
# gnuradio-companion 2
# pruning 2
# privileges 2
# swarmplot 2
# distributed-system 2
# gerrit 2
# python-unittest.mock 2
# facebook-messenger 2
# sharding 2
# sas 2
# rospy 2
# data-import 2
# py-datatable 2
# sql-delete 2
# double-click 2
# jvm 2
# names 2
# django-activity-stream 2
# colon 2
# python-datamodel 2
# executemany 2
# single-quotes 2
# proto 2
# subnet 2
# azure-keyvault 2
# corpus 2
# dimensions 2
# where 2
# spectrogram 2
# algorithmic-trading 2
# yellowbrick 2
# scrapy-pipeline 2
# autocad 2
# python-language-server 2
# labview 2
# expect 2
# driver 2
# header-files 2
# scikit-multilearn 2
# antivirus 2
# moto 2
# coordinate 2
# graphene-django 2
# ...
# luabind 1
# template-method-pattern 1
# plpy 1
# error-log 1
# python-2.2 1
# appstats 1
# string-search 1
# textmate2 1
# keystroke 1
# jcc 1
# ps3 1
# openkinect 1
# google-search-api 1
# nested-class 1
# kinect 1
# floating-point-exceptions 1
# emoticons 1
# backbone.js 1
# subcommand 1
# coin-change 1
# poplib 1
# simperium 1
# vbo 1
# class-factory 1
# sorteddictionary 1
# string-parsing 1
# playlist 1
# mockups 1
# callable-object 1
# windows-security 1
# android-activity 1
# removechild 1
# common-lisp 1
# imp 1
# pre-commit-hook 1
# media-url 1
# dummy-data 1
# graphicsmagick 1
# google-shopping-api 1
# mouse-cursor 1
# name-binding 1
# bad-request 1
# stargate 1
# propertydescriptor 1
# condition-variable 1
# rubypython 1
# tablerow 1
# bmp 1
# starcluster 1
# qpainter 1
# facade 1
# rubymine 1
# django-rosetta 1
# redraw 1
# mkdirs 1
# fedora16 1
# utf-16 1
# random-testing 1
# scramble 1
# jsrender 1
# plane 1
# quit 1
# django-1.3 1
# test-suite 1
# rsyslog 1
# linker-errors 1
# httpurlconnection 1
# rpython 1
# ssh-keys 1
# rsa-key-fingerprint 1
# ignore-case 1
# email-bounces 1
# facebook-opengraph 1
# language-comparisons 1
# abstraction 1
# django-evolution 1
# suffix-array 1
# lepl 1
# http-status-code-505 1
# ancestor 1
# suffix-tree 1
# x86 1
# iterm 1
# formwizard 1
# alchemyapi 1
# simultaneous-calls 1
# phpbb3 1
# deduplication 1
# review-board 1
# vb6 1
# mapnik 1
# windows-authentication 1
# ftputil 1
# fread 1
# keep-alive 1
# latent-semantic-indexing 1
# django-sites 1
# rm 1
# facebook-fql 1
# accessor 1
# zcml 1
# data-extraction 1
# nested-attributes 1
# macropy 1
# functional-testing 1
# nstask 1
# linguistics 1
# undefined-behavior 1
# django-postgresql 1
# data-acquisition 1
# text-analysis 1
# copy-on-write 1
# single-responsibility-principle 1
# sequence-alignment 1
# form-fields 1
# specialization 1
# microsoft-metro 1
# qrect 1
# compiler-warnings 1
# isodate 1
# netbeans-7 1
# worldwind 1
# less-unix 1
# google-cloud-messaging 1
# persian 1
# sigterm 1
# jackson 1
# first-class 1
# idempotent 1
# include-path 1
# form-submit 1
# pcre 1
# geography 1
# figures 1
# fancybox-2 1
# starttls 1
# density-plot 1
# su 1
# avx 1
# right-to-left 1
# output-formatting 1
# watchdog 1
# torque 1
# multiple-versions 1
# hard-drive 1
# urwid 1
# elastic-map-reduce 1
# comparator 1
# google-closure-library 1
# tkinter-scrolledtext 1
# vizard 1
# tomcat6 1
# internet-explorer-8 1
# couchdb-python 1
# private-members 1
# ca 1
# systrace 1
# qiime 1
# channel-api 1
# usability 1
# hmacsha1 1
# ansible-runner 1
# svmlight 1
# z3c.form 1
# genericsetup 1
# qsub 1
# qtreewidgetitem 1
# swing 1
# qlistview 1
# readprocessmemory 1
# x509 1
# public 1
# qgraphicsitem 1
# tex 1
# socket-timeout-exception 1
# xcode4.6 1
# two-way 1
# helpers 1
# screen-size 1
# minify 1
# session-state 1
# ndk-gdb 1
# dde 1
# entity-system 1
# retina 1
# circusd 1
# components 1
# void 1
# cpu-architecture 1
# robots.txt 1
# google-custom-search 1
# satisfiability 1
# picosat 1
# berkeley-db 1
# google-profiles-api 1
# google-shared-contacts 1
# signal-handling 1
# punjab 1
# hidden-field 1
# gtktextview 1
# gtkscrolledwindow 1
# ebay-api 1
# grequests 1
# slide 1
# tableofcontents 1
# osascript 1
# excel-2010 1
# load-balancing 1
# exiv2 1
# pyexiv2 1
# fiddler 1
# variable-length 1
# primitive-types 1
# maximize-window 1
# wso2esb 1
# mediator 1
# intel-fortran 1
# nxt 1
# rpn 1
# air 1
# strophe 1
# cidr 1
# vps 1
# rfc3339 1
# windows-server-2008 1
# database-normalization 1
# wnet 1
# vmware-workstation 1
# mono 1
# oursql 1
# lsf 1
# chmod 1
# rfc1035 1
# impacket 1
# komodo 1
# .netrc 1
# qtconsole 1
# cross-apply 1
# django-i18n 1
# pug 1
# pyjade 1
# django-pipeline 1
# system-tray 1
# rot13 1
# hstore 1
# heapq 1
# access-violation 1
# unmanaged 1
# remoteapi 1
# reboot 1
# router 1
# erlang-ports 1
# sgp4 1
# collapse 1
# language-binding 1
# finite-automata 1
# ramdisk 1
# gmp 1
# lynx 1
# recording 1
# remote-server 1
# specifications 1
# post-redirect-get 1
# wysiwyg 1
# maildir 1
# real-time-data 1
# askbot 1
# codeigniter 1
# type-inference 1
# logical-and 1
# debug-symbols 1
# angstrom-linux 1
# vimeo 1
# graphicscontext 1
# des 1
# propagation 1
# implicit-conversion 1
# p4v 1
# paypal-adaptive-payments 1
# vbulletin 1
# slackware 1
# zenoss 1
# google-glass 1
# symbol-table 1
# filemtime 1
# backreference 1
# import-from-csv 1
# soapserver 1
# ladon 1
# google-sites 1
# classpath 1
# utf8-decode 1
# mongokit 1
# freedesktop.org 1
# nipype 1
# heapy 1
# gawk 1
# testability 1
# cpu-registers 1
# portal 1
# long-parameter-list 1
# cut 1
# freebasic 1
# tile 1
# command-line-tool 1
# api-key 1
# ups 1
# utility 1
# fat32 1
# point-in-polygon 1
# 3g-network 1
# map-projections 1
# sfml 1
# rhino3d 1
# userid 1
# visual-c++-6 1
# entities 1
# sql-injection 1
# ear 1
# twisted.conch 1
# fdf 1
# mainframe 1
# rabin-karp 1
# erp 1
# rosalind 1
# du 1
# smtpclient 1
# ttl 1
# topology 1
# behavior 1
# sdn 1
# catia 1
# mysql-error-1064 1
# silent 1
# protobuf-net 1
# setsid 1
# changelog 1
# invitation 1
# silhouette 1
# artificial-life 1
# fuzzy-comparison 1
# lcs 1
# ceph 1
# invite 1
# rawstring 1
# tess4j 1
# gmm 1
# nosuchfileexception 1
# netscape 1
# datefield 1
# boost-asio 1
# ambari 1
# opencv3.3 1
# graphql-js 1
# python-install 1
# flask-extensions 1
# yahoo-boss-api 1
# osc 1
# cheroot 1
# python-cloudant 1
# unmanagedexports 1
# aws-step-functions 1
# datediff 1
# psse 1
# logbook 1
# xarray 1
# django-widget 1
# flask-sockets 1
# rodeo 1
# pdf-scraping 1
# chocolatey 1
# libcrypto 1
# postgrest 1
# image-thresholding 1
# email-verification 1
# swagger-codegen 1
# pybuilder 1
# matrix-inverse 1
# protoc 1
# jquery-file-upload 1
# blueimp 1
# xstream 1
# ubuntu-16.10 1
# google-places 1
# return-type 1
# max-msp-jitter 1
# flycapture 1
# piano 1
# sikuli-script 1
# state-pattern 1
# numpy-ufunc 1
# insert-into 1
# legacy 1
# snappydata 1
# snappydb 1
# isspace 1
# httpwebresponse 1
# psyco 1
# modular 1
# wolfram-mathematica 1
# mser 1
# european-data-format 1
# akamai 1
# pyro4 1
# aspell 1
# enchant 1
# col 1
# composite-key 1
# downloading-website-files 1
# pip3 1
# musixmatch 1
# disk-io 1
# uploading 1
# http-status-code-405 1
# paradox 1
# markov 1
# proxysql 1
# fbx 1
# picasa 1
# plistlib 1
# jenkins-blueocean 1
# static-cast 1
# stockquotes 1
# beyondcompare 1
# beyondcompare4 1
# android-recyclerview 1
# image-scanner 1
# isolation 1
# extended-ascii 1
# keystore 1
# pyjks 1
# ocaml 1
# classname 1
# armv7 1
# reserved-words 1
# xsd 1
# xsd-validation 1
# rewind 1
# mysql-cluster 1
# percona-xtradb-cluster 1
# music-notation 1
# comtypes 1
# autoload 1
# mathematical-morphology 1
# google-finance-api 1
# data-transfer-objects 1
# afnetworking 1
# edx 1
# windows-vista 1
# conflicting-libraries 1
# egnyte 1
# economics 1
# modelchoicefield 1
# winbugs 1
# openbugs 1
# image-morphology 1
# lambdify 1
# symantec 1
# azure-table-storage 1
# apache2-module 1
# minimalmodbus 1
# docker-machine 1
# assertraises 1
# linaro 1
# cmp 1
# numerical 1
# hashtag 1
# qsignalmapper 1
# sidekit 1
# tf-slim 1
# code-reuse 1
# asteriskami 1
# qtimer 1
# multiple-conditions 1
# elasticsearch-5 1
# clients 1
# iminuit 1
# jpeg2000 1
# google-cloud-logging 1
# sbt 1
# gdi 1
# genetic 1
# stripe-connect 1
# mongoose 1
# floor-division 1
# snapcraft 1
# actions-on-google 1
# google-home 1
# dajaxice 1
# messages 1
# google-cloud-ml-engine 1
# deflate 1
# inflate 1
# mdichild 1
# gephi 1
# whois 1
# blockingqueue 1
# checkinstall 1
# http-get 1
# linechart 1
# template-matching 1
# sprox 1
# turbogears 1
# flasgger 1
# inorder 1
# pymunk 1
# pyaudioanalysis 1
# webbrowser-control 1
# autoscroll 1
# imposition 1
# rabbitmqctl 1
# busy-waiting 1
# pyforms 1
# django-tagging 1
# nvidia-docker 1
# continuation 1
# workspace 1
# caffe2 1
# cleardb 1
# facebook-workplace 1
# external-script 1
# paragraph 1
# steam 1
# templating 1
# pdf-viewer 1
# persistent-connection 1
# object-lifetime 1
# in-class-initialization 1
# data-dump 1
# quoted-printable 1
# sysv 1
# opennlp 1
# pxssh 1
# tensorlayer 1
# portfolio 1
# openscad 1
# mean-square-error 1
# group-concat 1
# client-side-attacks 1
# regularized 1
# perplexity 1
# gksudo 1
# flask-jwt 1
# text-alignment 1
# speech-synthesis 1
# micro-optimization 1
# narray 1
# keycode 1
# text-segmentation 1
# check-mk 1
# concrete 1
# cpu-load 1
# dht 1
# page-refresh 1
# pybel 1
# google-news 1
# omniorb 1
# janusgraph 1
# embedded-language 1
# mechanicalsoup 1
# html-content-extraction 1
# aes-gcm 1
# openmodelica 1
# fmi 1
# dropzone.js 1
# sqldf 1
# sql-parametrized-query 1
# alert 1
# ironruby 1
# file-extension 1
# telegram-webhook 1
# google-cloud-speech 1
# google-assist-api 1
# computed-field 1
# ssm 1
# iis-10 1
# python-standalone 1
# docker-for-mac 1
# openbabel 1
# xonsh 1
# xgettext 1
# molecule 1
# adodb 1
# pybinding 1
# escpos 1
# watson-nlu 1
# backticks 1
# git-review 1
# drive 1
# lemur 1
# tkmessagebox 1
# tomcat8 1
# networkmanager 1
# instructions 1
# swagger-ui 1
# python-pool 1
# mailing 1
# chardet 1
# pylintrc 1
# toolchain 1
# pyramid-arima 1
# mysql-8.0 1
# gpflow 1
# bower 1
# django-scheduler 1
# wunderground 1
# turi 1
# layer 1
# azkaban 1
# pyp 1
# spatialite 1
# patsy 1
# webots 1
# utf8mb4 1
# between 1
# pact 1
# pact-python 1
# anti-patterns 1
# windows64 1
# text-indent 1
# seq 1
# pyx 1
# predictive 1
# encoder-decoder 1
# pad 1
# brackets 1
# odoo-view 1
# java-native-interface 1
# alexa-rank 1
# powercfg 1
# django-wkhtmltopdf 1
# basehttprequesthandler 1
# netflix-eureka 1
# lua-telegram-bot 1
# php-telegram-bot 1
# neo4j-python-driver 1
# django-modeladmin 1
# pusher 1
# selectize.js 1
# gnome-shell 1
# avsc 1
# datadog 1
# quantile 1
# describe 1
# illegalargumentexception 1
# in-memory 1
# build-tools 1
# isolation-level 1
# system32 1
# virtual 1
# background-image 1
# onload-event 1
# olpc 1
# flask-appbuilder 1
# experimental-design 1
# app-engine-flexible 1
# jupyterhub 1
# circular-list 1
# redis-server 1
# qsqlquerymodel 1
# oledb 1
# movie 1
# number-theory 1
# formfield 1
# google-static-maps 1
# dynamic-import 1
# unison 1
# snappy 1
# pyorient 1
# multiple-value 1
# django-filters 1
# square-connect 1
# script-debugging 1
# google-wave 1
# delete-operator 1
# achievements 1
# robotjs 1
# django-nose 1
# tiled 1
# taglib 1
# timeslots 1
# inproc 1
# href 1
# orientation 1
# pyicu 1
# requests-futures 1
# mecab 1
# datalist 1
# django-upgrade 1
# lifelines 1
# cox 1
# cox-regression 1
# entity 1
# soundex 1
# code-cleanup 1
# laspy 1
# runas 1
# u-sql 1
# accordion 1
# vpc 1
# code-structure 1
# lbph-algorithm 1
# wampserver 1
# service-principal 1
# google-cloud-endpoints-v2 1
# http-status-code-503 1
# lotus 1
# passenger 1
# pmw 1
# multiple-axes 1
# image-size 1
# detect 1
# lotus-notes 1
# builder 1
# mixed-models 1
# timetable 1
# threaded-comments 1
# adal 1
# cairoplot 1
# timescaledb 1
# dbm 1
# applocker 1
# fftpack 1
# logparser 1
# malformed 1
# chrome-profile 1
# restsharp 1
# timestamp-with-timezone 1
# kernel-methods 1
# aircrack-ng 1
# controlled-folder-access 1
# late-binding 1
# couchapp 1
# google-deployment-manager 1
# xtemplate 1
# type-annotation 1
# restful-url 1
# seq2seq 1
# underscore.js 1
# pandas-loc 1
# google-cloud-sdk 1
# rgbcolor 1
# deconvolution 1
# rotatetransform 1
# api-authorization 1
# bbc-microbit 1
# rfcomm 1
# pygsheets 1
# openconnect 1
# qemu 1
# roman-numerals 1
# bufferedreader 1
# dll-search-path 1
# disconnection 1
# qlistwidgetitem 1
# recreate 1
# oracle12c 1
# incron 1
# collaboration 1
# equals-operator 1
# msgpack 1
# valgrind 1
# ingres 1
# wordpress-rest-api 1
# oauth-1.0a 1
# rsa-sha256 1
# windows-server-2012-r2 1
# offset 1
# aws-cognito 1
# win32ole 1
# plone-4.x 1
# dexterity 1
# omnicomplete 1
# rdiff-backup 1
# openembedded 1
# myhdl 1
# producer 1
# message-bus 1
# generics 1
# duplicity 1
# dronekit 1
# spyne 1
# stochastic 1
# facebook-apps 1
# glfw 1
# singlestore 1
# cstringio 1
# streamline 1
# odoo-accounting 1
# split-apply-combine 1
# magic-function 1
# natsort 1
# curly-braces 1
# functor 1
# non-latin 1
# codepoint 1
# mfcc 1
# lettuce 1
# digit 1
# os.execl 1
# vcenter 1
# objectinstantiation 1
# ogg 1
# processing-efficiency 1
# primality-test 1
# min-heap 1
# boxsizer 1
# openvpn 1
# google-base 1
# flask-peewee 1
# basho-client 1
# google-apps-script 1
# ujson 1
# custom-fields 1
# xaml 1
# user-controls 1
# ellipse 1
# direction 1
# npm-install 1
# isql 1
# step 1
# exiftool 1
# gaeunit 1
# perspectivecamera 1
# apache2.2 1
# pysolr 1
# dynamic-binding 1
# spectral 1
# elaphe 1
# virsh 1
# communication-protocol 1
# openlayers-3 1
# oslo 1
# json-ld 1
# linked-data 1
# lamp 1
# theano-cuda 1
# errbot 1
# password-protection 1
# gated-recurrent-unit 1
# library-design 1
# differentiation 1
# double-click-advertising 1
# blank-line 1
# django-floppyforms 1
# confidence-interval 1
# gui-design 1
# accumulate 1
# swampdragon 1
# setattribute 1
# apache-storm 1
# pyleus 1
# cellrenderer 1
# xen 1
# google-analytics-api 1
# lru 1
# dlib-python 1
# samba 1
# tramp 1
# simulated-annealing 1
# python-routes 1
# xdr 1
# ipython-sql 1
# equivalence 1
# digest 1
# loopback 1
# node-expat 1
# feedback 1
# maven-2 1
# aerospike-loader 1
# run-script 1
# maintainability 1
# fsm 1
# pwm 1
# wiringpi 1
# columnheader 1
# fabricjs 1
# file-exists 1
# http-live-streaming 1
# ambiguous 1
# openwrt 1
# mutagen 1
# cql 1
# hypertable 1
# dynamic-linking 1
# nat 1
# halide 1
# stan 1
# catalan 1
# syphon 1
# isnull 1
# mail-server 1
# aol 1
# coverity 1
# nls 1
# cocos2d-python 1
# der 1
# magic-square 1
# interpreted-language 1
# mutual-recursion 1
# dynamically-generated 1
# rspec 1
# test-kitchen 1
# weather-api 1
# openweathermap 1
# name-conflict 1
# arduino-ide 1
# alt 1
# surrogate-pairs 1
# msysgit 1
# str-replace 1
# immutable.js 1
# email-client 1
# html-to-pdf 1
# discovery 1
# process-management 1
# exuberant-ctags 1
# django-shop 1
# rust 1
# identification 1
# imghdr 1
# intel-galileo 1
# arduino-ultra-sonic 1
# d3.js 1
# nvd3.js 1
# google-apps-marketplace 1
# styleframe 1
# template-inheritance 1
# ucs2 1
# inspection 1
# nfs 1
# asynccallback 1
# passive-view 1
# mvp 1
# consistency 1
# smime 1
# vowpalwabbit 1
# gradlew 1
# user-warning 1
# getcwd 1
# wordsearch 1
# notify 1
# jsonlint 1
# object-initializer 1
# autocorrect 1
# hocr 1
# line-numbers 1
# embedded-script 1
# skbio 1
# gamepad 1
# integer-programming 1
# zendesk 1
# dtml 1
# screens 1
# tokyo-cabinet 1
# malloc 1
# pdftk 1
# zelle-graphics 1
# htop 1
# summernote 1
# imapclient 1
# algolia 1
# gradle 1
# texture2d 1
# managed-vm 1
# resume 1
# nolearn 1
# vim-plugin 1
# python-jedi 1
# uhd 1
# excel-2011 1
# character-class 1
# cocoa-touch 1
# monit 1
# calibration 1
# crud 1
# formview 1
# mozilla 1
# spidermonkey 1
# social-networking 1
# pdoc 1
# inspect-element 1
# user-inactivity 1
# rollbar 1
# connection-string 1
# httpd.conf 1
# livewires 1
# kairosdb 1
# diagonal 1
# object-literal 1
# boost-tuples 1
# opus 1
# flask-restless 1
# titan 1
# seed 1
# builtwith 1
# rendering 1
# file-access 1
# logout 1
# jive 1
# sdl-2 1
# pysdl2 1
# lifetime 1
# eclipse-rcp 1
# autosuggest 1
# strikethrough 1
# augmented-assignment 1
# object-oriented-database 1
# fine-uploader 1
# camelcasing 1
# tryton 1
# banana-pi 1
# db4o 1
# replication 1
# dump 1
# batch-rename 1
# nasm 1
# code-organization 1
# matlab-compiler 1
# ubuntu-15.04 1
# contiki 1
# access-control 1
# pyevolve 1
# spark-jobserver 1
# sentinel 1
# codeship 1
# sublime-anaconda 1
# restify 1
# mysql-error-1025 1
# genetics 1
# ssh.net 1
# theforeman 1
# bitvector 1
# bitbucket-pipelines 1
# and-operator 1
# plone-3.x 1
# commercial-application 1
# separating-axis-theorem 1
# bit-fields 1
# major-mode 1
# python.el 1
# licensing 1
# postgres-plpython 1
# objdump 1
# qt-maemo 1
# waitpid 1
# volatility 1
# watchman 1
# abstract-data-type 1
# facet-grid 1
# cycle 1
# apache-config 1
# lucene 1
# cross-entropy 1
# reparenting 1
# stocks 1
# zerorpc 1
# geocode 1
# copy-protection 1
# conflict 1
# invalid-argument 1
# packing 1
# contiguous 1
# winrm 1
# birthday-paradox 1
# pcf 1
# pysimplesoap 1
# designer 1
# slowdown 1
# exscript 1
# non-recursive 1
# code-analysis 1
# pageload 1
# x86-64 1
# cross-compiling 1
# construction 1
# python-exec 1
# fold 1
# compile-time 1
# gentoo 1
# dynamic-class-loaders 1
# elassandra 1
# odoo-mobile 1
# anova 1
# flat-file 1
# date-conversion 1
# adobe-analytics 1
# set-operations 1
# dot 1
# snapshot 1
# alexa-slot 1
# auto-indent 1
# houghlinesp 1
# connection-refused 1
# debian-7.6.0 1
# iperf3 1
# avaya 1
# sizeof 1
# deform 1
# filewriter 1
# consul 1
# browsable 1
# code-complexity 1
# lets-encrypt 1
# control-characters 1
# dynamic-arrays 1
# ftdi 1
# asp-classic 1
# openstack-horizon 1
# horizon 1
# subroutine 1
# evernote 1
# jedit 1
# cpu-speed 1
# sframe 1
# bacnet 1
# cognos-tm1 1
# volttron 1
# listctrl 1
# invalid-characters 1
# overlay 1
# coercion 1
# csr 1
# file-association 1
# uno 1
# gpib 1
# restful-authentication 1
# string.format 1
# big5 1
# parallel-testing 1
# selenium-grid2 1
# webtest 1
# photo 1
# django-admin-filters 1
# complextype 1
# raspbian-wheezy 1
# redmine 1
# redmine-api 1
# python-redmine 1
# autofilter 1
# strong-typing 1
# shared-hosting 1
# alluxio 1
# django-authopenid 1
# clojure 1
# window-resize 1
# text-manipulation 1
# asymptotic-complexity 1
# axes 1
# keychain 1
# pkcs#12 1
# function-fitting 1
# pgm 1
# gconf 1
# putty 1
# odo 1
# ubuntu-15.10 1
# reversion 1
# custom-authentication 1
# pybossa 1
# jxcore 1
# autocommit 1
# pull-queue 1
# instruments 1
# recvfrom 1
# prestashop 1
# unit-conversion 1
# adjacency-list 1
# sane 1
# pyinsane 1
# pyvmomi 1
# orc 1
# checkboxlist 1
# m2m 1
# listiterator 1
# ibm-midrange 1
# db2-400 1
# xml-serialization 1
# hmmlearn 1
# django-uploads 1
# caret 1
# pysam 1
# graphframes 1
# zope.component 1
# hl7 1
# tm 1
# hl7-v2 1
# hl7-v3 1
# pyzo 1
# shogun 1
# scriptengine 1
# emacs-jedi 1
# appium-ios 1
# core 1
# unions 1
# dynamic-typing 1
# openglcontext 1
# future 1
# implicit 1
# explicit 1
# browsermob 1
# linux-device-driver 1
# suitecrm 1
# eclipse-3.5 1
# address-sanitizer 1
# spatial 1
# django-select-related 1
# django-custom-tags 1
# vhdl 1
# terra 1

# %%
question_with_code_description_raw = pd.read_csv('/home/st-aleksandr-razin/workspace/SRC_QC4QA/data/summarization/final/question_with_code_description_raw.csv')
question_with_code_description_raw
# Out:
#            Id_Q                                            Title_Q  \
# 0          1476      How do you express binary literals in Python?
# 1         20927  Updating an auto_now DateTimeField in a parent...
# 2         59825  How to retrieve an element from a set without ...
# 3         61605  Is it pythonic for a function to return multip...
# 4         65266          Caching compiled regex objects in Python?
# ...         ...                                                ...
# 49990  72498913  Pyngrok & Flask, Your account is limited to 1 ...
# 49991  72500796  How to fix ModuleNotFoundError: No module name...
# 49992  72502170         How to drop duplicates ignoring one column
# 49993  72502242  django.db.utils.ProgrammingError: relation "ap...
# 49994  72505151  Printing gives the answer I want, but returnin...
#
#                                                   Body_Q  \
# 0      <p>How do you express an integer as a binary n...
# 1      <p>I've got two models: Message and Attachment...
# 2      <p>Suppose the following:</p>\n\n<pre><code>&g...
# 3      <p>In python, you can have a function return m...
# 4      <p>Each time a python file is imported that co...
# ...                                                  ...
# 49990  <p>I trying to run both flask and ngrok in the...
# 49991  <p>I have currently installed the terra_sdk==2...
# 49992  <p>I have a <code>DataFrame</code> with multip...
# 49993  <p>After I deleted all the migration files and...
# 49994  <p>I'm quite new to python and ive been practi...
#
#                                                   Tags_Q  Code_Q
# 0      ['python', 'syntax', 'binary', 'integer', 'lit...    True
# 1                ['python', 'database', 'django', 'orm']    True
# 2                                      ['python', 'set']    True
# 3      ['python', 'function', 'return-value', 'multip...    True
# 4                         ['python', 'regex', 'caching']    True
# ...                                                  ...     ...
# 49990  ['python', 'r', 'python-3.x', 'flask', 'pyngrok']    True
# 49991                                ['python', 'terra']    True
# 49992                               ['python', 'pandas']    True
# 49993          ['python', 'django', 'django-migrations']    True
# 49994                 ['python', 'python-3.x', 'return']    True
#
# [49995 rows x 5 columns]

# %%
for i in question_with_code_description['Body_Q'].values[1:]:
    print(i)
    break
# Out:
# <p>I've got two models: Message and Attachment. Each attachment is attached to a specific message, using a ForeignKey on the Attachment model. Both models have an auto_now DateTimeField called updated. I'm trying to make it so that when any attachment is saved, it also sets the updated field on the associated message to now. Here's my code:</p>
#
# code description start: Save attachment to the database. code description end
#
# <p>Will this work, and if you can explain it to me, why? If not, how would I accomplish this?</p>

# %%
for i in question_with_code_description_raw['Body_Q'].values[1:]:
    print(i)
    break
# Out:
# <p>I've got two models: Message and Attachment. Each attachment is attached to a specific message, using a ForeignKey on the Attachment model. Both models have an auto_now DateTimeField called updated. I'm trying to make it so that when any attachment is saved, it also sets the updated field on the associated message to now. Here's my code:</p>
#
# <pre><code>def save(self):
#     super(Attachment, self).save()
#     self.message.updated = self.updated
# </code></pre>
#
# <p>Will this work, and if you can explain it to me, why? If not, how would I accomplish this?</p>

# %%
from datasets import load_dataset

# %%
question_with_code_description_raw.to_json('/home/st-aleksandr-razin/workspace/SRC_QC4QA/data/summarization/final/question_without_code_description.json', orient='records')

dataset = load_dataset(
    "json",
    data_files={
        "train": "/home/st-aleksandr-razin/workspace/SRC_QC4QA/data/summarization/final/question_without_code_description.json",
    },
)
# Out:
# Downloading and preparing dataset json/default to /home/st-aleksandr-razin/.cache/huggingface/datasets/json/default-85e08b30374667f5/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset json downloaded and prepared to /home/st-aleksandr-razin/.cache/huggingface/datasets/json/default-85e08b30374667f5/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
